# %% [markdown]
# <a href="https://colab.research.google.com/github/AvantiShri/gcp_analysis_rough/blob/main/cleaner/BulkAnalyze_maxsmooth_timedomain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
from matplotlib import pyplot as plt
from IPython.display import Image
import scipy
import time

def max_and_maxabs_over_smoothing_windows_1darr(arr, windowsize):
  arr_cumsum = np.array([0] + list(np.cumsum(arr)))
  #under the hypothesis of white noise, each entry is iid. Let v represent
  # the variance of each power. The variance of the sum in a window
  # is v*window, so the variances across different window sizes can be
  # normalized by dividing by sqrt(window).
  arr_normalized = (arr_cumsum[windowsize:]
                    - arr_cumsum[:-windowsize])/np.sqrt(windowsize)
  return np.max(arr_normalized), np.max(np.abs(arr_normalized))

def max_and_maxabs_over_different_smoothing_windows_2darr(arrs, windowsize):
  arrs_cumsum = np.pad(np.cumsum(arrs, axis=1), ((0,0),(1,0)))
  arrs_normalized = (arrs_cumsum[:,windowsize:]
                      - arrs_cumsum[:,:-windowsize])/np.sqrt(windowsize)
  return np.max(arrs_normalized, axis=1), np.max(np.abs(arrs_normalized), axis=1)

def perform_analysis(values, num_permutations):

  toreturndict = {}

  start = time.time()
  rng = np.random.RandomState(1234)
  rng_permutations = np.array([rng.permutation(values)
                               for i in range(num_permutations)])

  windowsizes = [60, 300, 600, 900]

  for windowsize in windowsizes:
    max, maxabs = max_and_maxabs_over_smoothing_windows_1darr(values, windowsize)
    max_permute, maxabs_permute = max_and_maxabs_over_different_smoothing_windows_2darr(rng_permutations, windowsize)
    pval_max = np.mean(max_permute >= max)
    pval_maxabs = np.mean(maxabs_permute >= maxabs)
    toreturndict['pval_maxwindow'+str(windowsize)] = pval_max
    toreturndict['val_maxwindow'+str(windowsize)] = max
    toreturndict['pval_maxabswindow'+str(windowsize)] = pval_maxabs
    toreturndict['val_maxabswindow'+str(windowsize)] = maxabs

  return toreturndict

# %%
def get_chisquareminus1(egg_values):
  #print("Num nan:", np.sum(np.isnan(egg_values)))
  #Radin 2023 (Anomalous entropic effects in physical systems associated
  # with collective consciousness) said "All individual samples within a matrix
  # less than 55 or greater than 145 were set to nan" so we do that here
  egg_values = np.where((egg_values < 55), np.nan, egg_values)
  egg_values = np.where((egg_values > 145), np.nan, egg_values)
  #print("Num nan post mask:", np.sum(np.isnan(egg_values)))

  num_nonnan_eggs = np.sum(np.isnan(egg_values)==False, axis=1) #get the number of non NaN eggs per row
  #If any rows are all-nan, aboort as if we dropped that row it would mess
  # up the temporal spacing
  #assert (np.sum(num_nonnan_eggs==0)==0), np.sum(num_nonnan_eggs==0)

  sum_eggs = np.nansum(egg_values, axis=1) #get the sum across all eggs - NaNs are automatically skipped
  z_sum_eggs = (sum_eggs - num_nonnan_eggs*100)/np.sqrt(num_nonnan_eggs*200*0.25) #get z scores as per a binomial dist

  return np.square(z_sum_eggs)-1, z_sum_eggs

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
event_metadata_list = json.load(open("/content/drive/MyDrive/GCP_data/event_metadata_list.json"))

# %%
# %matplotlib inline

import glob
import json
import numpy as np
import scipy
import os
from matplotlib import pyplot as plt
import time

# %cd /content/drive/MyDrive/GCP_data/

NUM_PERMUTATIONS = 1000

generalstats = {"test": [], "control1": [], "control2": [], "control3": [],
                "control4": [], "control5": [], "control6": []}
csm1_psanalysis = {"test": [], "control1": [], "control2": [], "control3": [],
                   "control4": [], "control5": [], "control6": []}
compositez_psanalysis = {"test": [], "control1": [], "control2": [],
                         "control3": [], "control4": [], "control5": [], "control6": []}

event_count = 0

dont_rerun_if_cache_file_exists = True #If False, rerun the call the perform_powerspectrum_analysis
cachesavefolder = "/content/drive/MyDrive/GCP_data/analysis/maxandmaxabswindow/"
# !mkdir $cachesavefolder

for (event, event_name, pval) in event_metadata_list[:]:

  event_count += 1
  print("\n--------------------------------")
  print("Event Count:",event_count,event,event_name,pval)

  for spanname in ['test', 'control1', 'control2']:#, 'control3', 'control4', 'control5', 'control6']:
    print("span:", spanname)
    egg_values = np.load("extracted/"+event+"_"+spanname+"_eggvalues.npy")

    csm1, z_sum_eggs = get_chisquareminus1(egg_values)

    csm1_zscore = np.sum(csm1)/np.sqrt(2*len(csm1)) #variance of chi-squared with df=1 is 2

    spangeneralstats = {
      'csm1_zscore': csm1_zscore,
      'length': len(csm1)}
    generalstats[spanname].append(spangeneralstats)

    print(spanname, spangeneralstats)

    for signaltype,signal,signalsavedict in [("csm1", csm1, csm1_psanalysis),
                                             ("compositez", z_sum_eggs, compositez_psanalysis)
                                             ]:
      start = time.time()
      saveprefix = cachesavefolder+"/"+event+"_"+spanname+"_"+signaltype+"_nperm-"+str(NUM_PERMUTATIONS)
      if (dont_rerun_if_cache_file_exists and os.path.exists(saveprefix+"_psanalysis.json")):
        ps_analysis = json.load(open(saveprefix+"_psanalysis.json"))
      else:
        ps_analysis = perform_analysis(signal, NUM_PERMUTATIONS)
        open(saveprefix+"_psanalysis.json",'w').write(json.dumps(ps_analysis))
      print(signaltype, ps_analysis, time.time()-start)
      signalsavedict[spanname].append(ps_analysis)
# Out:
# /content/drive/MyDrive/GCP_data
# mkdir: cannot create directory ‘/content/drive/MyDrive/GCP_data/analysis/maxandmaxabswindow/’: File exists
#
# --------------------------------
# Event Count: 1 Event391 Internat Day Peace 0.0008192443394802185
# span: test
# test {'csm1_zscore': 3.148966694327055, 'length': 86400}
# csm1 {'pval_maxwindow60': 0.999, 'val_maxwindow60': 5.542735704749163, 'pval_maxabswindow60': 0.999, 'val_maxabswindow60': 5.542735704749163, 'pval_maxwindow300': 0.395, 'val_maxwindow300': 5.940512637721329, 'pval_maxabswindow300': 0.396, 'val_maxabswindow300': 5.940512637721329, 'pval_maxwindow600': 0.186, 'val_maxwindow600': 6.038347274209325, 'pval_maxabswindow600': 0.188, 'val_maxabswindow600': 6.038347274209325, 'pval_maxwindow900': 0.328, 'val_maxwindow900': 5.504248878205207, 'pval_maxabswindow900': 0.33, 'val_maxabswindow900': 5.504248878205207} 0.685570478439331
# span: control2
# control2 {'csm1_zscore': -0.32324841247988423, 'length': 50100}
# csm1 {'pval_maxwindow60': 0.347, 'val_maxwindow60': 6.656946099331256, 'pval_maxabswindow60': 0.347, 'val_maxabswindow60': 6.656946099331256, 'pval_maxwindow300': 0.898, 'val_maxwindow300': 4.366842581803563, 'pval_maxabswindow300': 0.949, 'val_maxabswindow300': 4.366842581803563, 'pval_maxwindow600': 0.702, 'val_maxwindow600': 4.307948581192731, 'pval_maxabswindow600': 0.839, 'val_maxabswindow600': 4.307948581192731, 'pval_maxwindow900': 0.36, 'val_maxwindow900': 4.54023709331775, 'pval_maxabswindow900': 0.49, 'val_maxabswindow900': 4.54023709331775} 4.144542932510376
# compositez {'pval_maxwindow60': 0.45, 'val_maxwindow60': 3.81969990243118, 'pval_maxabswindow60': 0.6, 'val_maxabswindow60': 3.9147764401394904, 'pval_maxwindow300': 0.73, 'val_maxwindow300': 3.134751632364225, 'pval_maxabswindow300': 0.938, 'val_maxabswindow300': 3.134751632364225, 'pval_maxwindow600': 0.384, 'val_maxwindow600': 3.1869727067164204, 'pval_maxabswindow600': 0.674, 'val_maxabswindow600': 3.1869727067164204, 'pval_maxwindow900': 0.508, 'val_maxwindow900': 2.927348264186791, 'pval_maxabswindow900': 0.703, 'val_maxabswindow900': 3.030033822779835} 4.1391212940216064
#
# --------------------------------
# Event Count: 12 Event437 Dr. Tomorrow Passes 0.01899878662499621
# span: test
# test {'csm1_zscore': 2.0748809114285947, 'length': 21600}
# csm1 {'pval_maxwindow60': 0.086, 'val_maxwindow60': 7.123830816751595, 'pval_maxabswindow60': 0.086, 'val_maxabswindow60': 7.123830816751595, 'pval_maxwindow300': 0.405, 'val_maxwindow300': 5.143498078156529, 'pval_maxabswindow300': 0.407, 'val_maxabswindow300': 5.143498078156529, 'pval_maxwindow600': 0.825, 'val_maxwindow600': 4.114534106788126, 'pval_maxabswindow600': 0.827, 'val_maxabswindow600': 4.132942393339955, 'pval_maxwindow900': 0.611, 'val_maxwindow900': 4.317963187429846, 'pval_maxabswindow900': 0.618, 'val_maxabswindow900': 4.317963187429846} 1.8044049739837646
# compositez {'pval_maxwindow60': 0.936, 'val_maxwindow60': 3.119138381416292, 'pval_maxabswindow60': 0.156, 'val_maxabswindow60': 4.153106905642692, 'pval_maxwindow300': 0.335, 'val_maxwindow300': 3.2654585273647845, 'pval_maxabswindow300': 0.459, 'val_maxabswindow300': 3.3458288822190085, 'pval_maxwindow600': 0.486, 'val_maxwindow600': 2.8689587370925143, 'pval_maxabswindow600': 0.351, 'val_maxabswindow600': 3.2315491172144823, 'pval_maxwindow900': 0.727, 'val_maxwindow900': 2.4543679434635806, 'pval_maxabswindow900': 0.256, 'val_maxabswindow900': 3.189014540163423} 1.791649580001831
# span: control1
# control1 {'csm1_zscore': 1.5493434562556672, 'length': 21600}
# compositez {'pval_maxwindow60': 0.252, 'val_maxwindow60': 3.823925557155454, 'pval_maxabswindow60': 0.394, 'val_maxabswindow60': 3.823925557155454, 'pval_maxwindow300': 0.976, 'val_maxwindow300': 2.4572027456710477, 'pval_maxabswindow300': 0.899, 'val_maxabswindow300': 2.899710961140826, 'pval_maxwindow600': 0.241, 'val_maxwindow600': 3.1883445428615365, 'pval_maxabswindow600': 0.43, 'val_maxabswindow600': 3.1883445428615365, 'pval_maxwindow900': 0.056, 'val_maxwindow900': 3.526605751399351, 'pval_maxabswindow900': 0.122, 'val_maxabswindow900': 3.526605751399351} 1.7875566482543945
# span: control1
# control1 {'csm1_zscore': -1.6482068831834964, 'length': 21600}
# ...
#
# --------------------------------
# Event Count: 37 Event422 Batman Shooting 0.05479502667170699
# span: test
# test {'csm1_zscore': 1.6000384522805455, 'length': 21600}
# csm1 {'pval_maxwindow60': 0.883, 'val_maxwindow60': 5.3781795938774675, 'pval_maxabswindow60': 0.883, 'val_maxabswindow60': 5.3781795938774675, 'pval_maxwindow300': 0.158, 'val_maxwindow300': 5.61686371486332, 'pval_maxabswindow300': 0.159, 'val_maxabswindow300': 5.61686371486332, 'pval_maxwindow600': 0.887, 'val_maxwindow600': 3.8678864703181426, 'pval_maxabswindow600': 0.899, 'val_maxabswindow600': 3.8678864703181426, 'pval_maxwindow900': 0.681, 'val_maxwindow900': 4.088299607843126, 'pval_maxabswindow900': 0.699, 'val_maxabswindow900': 4.088299607843126} 1.7753148078918457
# compositez {'pval_maxwindow60': 0.135, 'val_maxwindow60': 4.003557241783273, 'pval_maxabswindow60': 0.251, 'val_maxabswindow60': 4.003557241783273, 'pval_maxwindow300': 0.922, 'val_maxwindow300': 2.5736221010385827, 'pval_maxabswindow300': 0.567, 'val_maxabswindow300': 3.252756498202919, 'pval_maxwindow600': 0.539, 'val_maxwindow600': 2.724773123150513, 'pval_maxabswindow600': 0.18, 'val_maxabswindow600': 3.5175750151102867, 'pval_maxwindow900': 0.545, 'val_maxwindow900': 2.561142234671571, 'pval_maxabswindow900': 0.173, 'val_maxabswindow900': 3.3797036133603853} 1.7920541763305664
# span: control1
# control1 {'csm1_zscore': 1.1515850537841397, 'length': 21600}
# csm1 {'pval_maxwindow60': 0.564, 'val_maxwindow60': 5.903303521509813, 'pval_maxabswindow60': 0.564, 'val_maxabswindow60': 5.903303521509813, 'pval_maxwindow300': 0.077, 'val_maxwindow300': 5.897317091134167, 'pval_maxabswindow300': 0.078, 'val_maxabswindow300': 5.897317091134167, 'pval_maxwindow600': 0.214, 'val_maxwindow600': 5.065606410459077, 'pval_maxabswindow600': 0.224, 'val_maxabswindow600': 5.065606410459077, 'pval_maxwindow900': 0.433, 'val_maxwindow900': 4.3767924528301885, 'pval_maxabswindow900': 0.463, 'val_maxabswindow900': 4.3767924528301885} 1.7888693809509277
#
# --------------------------------
# Event Count: 39 Event69 Kumbh Mela, India 0.06031450366716651
# span: test
# test {'csm1_zscore': 1.552138835672499, 'length': 46800}
# csm1 {'pval_maxwindow60': 0.123, 'val_maxwindow60': 7.607487977265951, 'pval_maxabswindow60': 0.123, 'val_maxabswindow60': 7.607487977265951, 'pval_maxwindow300': 0.172, 'val_maxwindow300': 5.939253612075373, 'pval_maxabswindow300': 0.172, 'val_maxabswindow300': 5.939253612075373, 'pval_maxwindow600': 0.238, 'val_maxwindow600': 5.400492407265694, 'pval_maxabswindow600': 0.245, 'val_maxabswindow600': 5.400492407265694, 'pval_maxwindow900': 0.471, 'val_maxwindow900': 4.771013257575755, 'pval_maxabswindow900': 0.495, 'val_maxabswindow900': 4.771013257575755} 4.644773244857788
# compositez {'pval_maxwindow60': 0.562, 'val_maxwindow60': 3.6939165254386706, 'pval_maxabswindow60': 0.816, 'val_maxabswindow60': 3.72215101147341, 'pval_maxwindow300': 0.454, 'val_maxwindow300': 3.3203785566842554, 'pval_maxabswindow300': 0.219, 'val_maxabswindow300': 3.858978058342947, 'pval_maxwindow600': 0.419, 'val_maxwindow600': 3.102318591419876, 'pval_maxabswindow600': 0.453, 'val_maxabswindow600': 3.4043597549682505, 'pval_maxwindow900': 0.923, 'val_maxwindow900': 2.355723373744914, 'pval_maxabswindow900': 0.767, 'val_maxabswindow900': 2.952406872406979} 4.005593538284302
# span: control1
# control1 {'csm1_zscore': 0.27227508940724077, 'length': 46800}
# csm1 {'pval_maxwindow60': 0.249, 'val_maxwindow60': 6.803467392880381, 'pval_maxabswindow60': 0.249, 'val_maxabswindow60': 6.803467392880381, 'pval_maxwindow300': 0.355, 'val_maxwindow300': 5.298409028338336, 'pval_maxabswindow300': 0.373, 'val_maxabswindow300': 5.298409028338336, 'pval_maxwindow600': 0.491, 'val_maxwindow600': 4.650271224946689, 'pval_maxabswindow600': 0.561, 'val_maxabswindow600': 4.650271224946689, 'pval_maxwindow900': 0.742, 'val_maxwindow900': 4.004186868686864, 'pval_maxabswindow900': 0.861, 'val_maxabswindow900': 4.004186868686864} 3.9494495391845703
# compositez {'pval_maxwindow60': 0.94, 'val_maxwindow60': 3.335419178459376, 'pval_maxabswindow60': 0.43, 'val_maxabswindow60': 3.996488156508076, 'pval_maxwindow300': 0.521, 'val_maxwindow300': 3.281021501850427, 'pval_maxabswindow300': 0.797, 'val_maxabswindow300': 3.281021501850427, 'pval_maxwindow600': 0.702, 'val_maxwindow600': 2.8803994303740206, 'pval_maxabswindow600': 0.857, 'val_maxabswindow600': 2.990548964691132, 'pval_maxwindow900': 0.904, 'val_maxwindow900': 2.450972037196584, 'pval_maxabswindow900': 0.992, 'val_maxabswindow900': 2.450972037196584} 4.388544082641602
# span: control2
# control2 {'csm1_zscore': -0.9772830905774363, 'length': 46800}
# csm1 {'pval_maxwindow60': 0.937, 'val_maxwindow60': 5.41359076617303, 'pval_maxabswindow60': 0.937, 'val_maxabswindow60': 5.41359076617303, 'pval_maxwindow300': 0.119, 'val_maxwindow300': 5.698433778018378, 'pval_maxabswindow300': 0.128, 'val_maxabswindow300': 5.698433778018378, 'pval_maxwindow600': 0.151, 'val_maxwindow600': 5.116752659204598, 'pval_maxabswindow600': 0.218, 'val_maxabswindow600': 5.116752659204598, 'pval_maxwindow900': 0.321, 'val_maxwindow900': 4.3838983957219, 'pval_maxabswindow900': 0.4, 'val_maxabswindow900': 4.593671717171725} 3.8626160621643066
# compositez {'pval_maxwindow60': 0.528, 'val_maxwindow60': 3.778173661561064, 'pval_maxabswindow60': 0.36, 'val_maxabswindow60': 4.065496477663913, 'pval_maxwindow300': 0.839, 'val_maxwindow300': 3.1567148934631617, 'pval_maxabswindow300': 0.918, 'val_maxabswindow300': 3.1567148934631617, 'pval_maxwindow600': 0.971, 'val_maxwindow600': 2.7444698098077867, 'pval_maxabswindow600': 0.995, 'val_maxabswindow600': 2.7444698098077867, 'pval_maxwindow900': 0.641, 'val_maxwindow900': 3.0621857809696866, 'pval_maxabswindow900': 0.704, 'val_maxabswindow900': 3.0621857809696866} 3.894221067428589
#
# --------------------------------
# Event Count: 40 Event363 State of the Union 0.0620997002828273
# span: test
# test {'csm1_zscore': 1.5373835978835912, 'length': 7200}
# csm1 {'pval_maxwindow60': 0.032, 'val_maxwindow60': 7.404714487497131, 'pval_maxabswindow60': 0.032, 'val_maxabswindow60': 7.404714487497131, 'pval_maxwindow300': 0.375, 'val_maxwindow300': 4.7335899111842865, 'pval_maxabswindow300': 0.379, 'val_maxabswindow300': 4.7335899111842865, 'pval_maxwindow600': 0.468, 'val_maxwindow600': 4.128301615742975, 'pval_maxabswindow600': 0.475, 'val_maxabswindow600': 4.128301615742975, 'pval_maxwindow900': 0.834, 'val_maxwindow900': 3.26667417648062, 'pval_maxabswindow900': 0.712, 'val_maxabswindow900': 3.5068305171531122} 0.5814855098724365
# compositez {'pval_maxwindow60': 0.413, 'val_maxwindow60': 3.303113810718734, 'pval_maxabswindow60': 0.203, 'val_maxabswindow60': 3.774658609602676, 'pval_maxwindow300': 0.821, 'val_maxwindow300': 2.2756542572987395, 'pval_maxabswindow300': 0.828, 'val_maxabswindow300': 2.5435802229739255, 'pval_maxwindow600': 0.269, 'val_maxwindow600': 2.6196137921114535, 'pval_maxabswindow600': 0.48, 'val_maxabswindow600': 2.6196137921114535, 'pval_maxwindow900': 0.316, 'val_maxwindow900': 2.3158705614908612, 'pval_maxabswindow900': 0.495, 'val_maxabswindow900': 2.384981598241266} 0.7242341041564941
# span: control1
# control1 {'csm1_zscore': -0.05579399214883711, 'length': 7200}
# csm1 {'pval_maxwindow60': 0.371, 'val_maxwindow60': 5.234511174190025, 'pval_maxabswindow60': 0.372, 'val_maxabswindow60': 5.234511174190025, 'pval_maxwindow300': 0.963, 'val_maxwindow300': 2.8312872892124274, 'pval_maxabswindow300': 0.873, 'val_maxabswindow300': 3.389534743734995, 'pval_maxwindow600': 0.862, 'val_maxwindow600': 2.619894209707517, 'pval_maxabswindow600': 0.45, 'val_maxabswindow600': 3.661264735306294, 'pval_maxwindow900': 0.981, 'val_maxwindow900': 1.8158827444956454, 'pval_maxabswindow900': 0.594, 'val_maxabswindow900': 3.12268783068783} 0.5884480476379395
# compositez {'pval_maxwindow60': 0.091, 'val_maxwindow60': 3.822963198756642, 'pval_maxabswindow60': 0.145, 'val_maxabswindow60': 3.822963198756642, 'pval_maxwindow300': 0.01, 'val_maxwindow300': 4.131624009861086, 'pval_maxabswindow300': 0.01, 'val_maxabswindow300': 4.131624009861086, 'pval_maxwindow600': 0.009, 'val_maxwindow600': 4.054982065875251, 'pval_maxabswindow600': 0.009, 'val_maxabswindow600': 4.054982065875251, 'pval_maxwindow900': 0.0, 'val_maxwindow900': 4.111959083585772, 'pval_maxabswindow900': 0.0, 'val_maxabswindow900': 4.111959083585772} 0.5974628925323486
# span: control2
# control2 {'csm1_zscore': 0.6530802611367067, 'length': 7200}
# csm1 {'pval_maxwindow60': 0.638, 'val_maxwindow60': 5.040247247618347, 'pval_maxabswindow60': 0.638, 'val_maxabswindow60': 5.040247247618347, 'pval_maxwindow300': 0.517, 'val_maxwindow300': 4.121917602259278, 'pval_maxabswindow300': 0.569, 'val_maxabswindow300': 4.121917602259278, 'pval_maxwindow600': 0.826, 'val_maxwindow600': 3.113257356375259, 'pval_maxabswindow600': 0.712, 'val_maxabswindow600': 3.421823663846948, 'pval_maxwindow900': 0.749, 'val_maxwindow900': 2.916913807817039, 'pval_maxabswindow900': 0.791, 'val_maxabswindow900': 2.9254548557774367} 0.6411380767822266
# compositez {'pval_maxwindow60': 0.996, 'val_maxwindow60': 2.423404953680179, 'pval_maxabswindow60': 1.0, 'val_maxabswindow60': 2.5716443178158386, 'pval_maxwindow300': 0.139, 'val_maxwindow300': 3.056222673783656, 'pval_maxabswindow300': 0.342, 'val_maxabswindow300': 3.056222673783656, 'pval_maxwindow600': 0.754, 'val_maxwindow600': 1.8749532898734065, 'pval_maxabswindow600': 0.968, 'val_maxabswindow600': 1.90257080546441, 'pval_maxwindow900': 0.891, 'val_maxwindow900': 1.421340881589345, 'pval_maxabswindow900': 0.981, 'val_maxabswindow900': 1.6267467795413035} 0.5937662124633789
#
# --------------------------------
# Event Count: 41 Event131 Global Peace Demonstrations 0.06270343438943171
# span: test
# test {'csm1_zscore': 1.532468484876167, 'length': 86400}

# %%
import json

prefix = "/content/drive/MyDrive/GCP_data/analysis/nperm"+str(NUM_PERMUTATIONS)+"_maxandmaxabswindow_controls1and2"

#save the results
open(prefix+"_csm1_psanalysis.json","w").write(json.dumps(csm1_psanalysis, indent=4))
open(prefix+"_compositez_psanalysis.json","w").write(json.dumps(compositez_psanalysis, indent=4))

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/GCP_data

# %%
import json
import numpy as np
import scipy

NUM_PERMUTATIONS = 1000

#load the pvals in case we want to remake the plots without rerunning the prev stuff
prefix = "/content/drive/MyDrive/GCP_data/analysis/nperm"+str(NUM_PERMUTATIONS)+"_maxandmaxabswindow_controls1and2"

event_metadata_list = json.load(open("/content/drive/MyDrive/GCP_data/event_metadata_list.json"))
#generalstats = json.load(open("/content/drive/MyDrive/GCP_data/analysis/generalstats.json"))

csm1_psanalysis = json.load(open(prefix+"_csm1_psanalysis.json"))
compositez_psanalysis = json.load(open(prefix+"_compositez_psanalysis.json"))

# %%
import os

def get_meta_pval(pvals):
  chisquare_stat = -2*np.sum(np.log(pvals))
  deg_freedom = 2*len(pvals)
  return (1 - scipy.stats.chi2.cdf(chisquare_stat, df=deg_freedom))

def get_iterative_metapvals(pvals):
 return np.array([(get_meta_pval(pvals[:i+1])) for i in range(len(pvals))])

metatrends_to_sim = 5000
rng = np.random.RandomState(1234)
savefile = "/content/drive/MyDrive/GCP_data/analysis/simulated_metatrends_nperm"+str(metatrends_to_sim)+".npy"
if (os.path.isfile(savefile)):
  simulated_metapvals_arr = np.load(savefile)
else:
  simulated_metapvals_arr = np.array([
      get_iterative_metapvals(
        np.maximum(rng.uniform(size=len(csm1_psanalysis["test"])),
                  1.0/NUM_PERMUTATIONS)
      )
        for i in range(metatrends_to_sim)])
  np.save(savefile, simulated_metapvals_arr)

# %%
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import patches as mpatches
from IPython.core.display import Image, display

#plot how the meta pvalue changes with samples

min_meta = 1 # start the x axis here, min num to include in metaanalysis
max_meta = len(csm1_psanalysis["test"]) #where to stop the plot

def correct_pvals(pvals, m): #permutation p values should never be zero: https://www.degruyter.com/document/doi/10.2202/1544-6115.1585/html
  #'Let B be the number of times out of m that t_sim >= t_obs'
  Bs = pvals*m
  #Under the null hypothesis, B is uniformly distributed across all integers
  # ranging from 0 to m, and the probability of observing B <= b is (b+1)/(m+1)
  adjusted_pvals = (Bs+1)/(m+1)
  return adjusted_pvals

original_gcp_pvals = np.array([x[2] for x in event_metadata_list[:max_meta]])

def make_meta_trend_plot(title, uncorrected_pvals_loa, loa_names, loa_colors):
  # %matplotlib inline

  xaxis_slice = list(range(min_meta,max_meta+1))
  xaxis_full = list(range(1,max_meta+1))

  pvals_loa = [correct_pvals(arr, m=NUM_PERMUTATIONS) for arr in uncorrected_pvals_loa]
  metapvals_loa = [get_iterative_metapvals(arr) for arr in pvals_loa]

  theslice = slice(min_meta-1, max_meta)
  min_simmetapvals_arr = np.min(simulated_metapvals_arr[:,theslice], axis=1)

  pvalformetapvals_list = [correct_pvals(np.mean(min_simmetapvals_arr <= np.min(arr)),
                                         m=len(simulated_metapvals_arr))
                            for arr in metapvals_loa]

  pvalforrankbias_list = [
      scipy.stats.mannwhitneyu(x=arr[original_gcp_pvals < 0.5],
                               y=arr[original_gcp_pvals >= 0.5], alternative='less')[1]
      for arr in pvals_loa
  ]
  print("Testing for low meta-analysis p-values:")
  for arr_name, metatrendpval, rankbiaspval in zip(loa_names, pvalformetapvals_list, pvalforrankbias_list):
    print("meta-analysis p-value:",arr_name,"pval:",metatrendpval)
    print("Rankbias p-value:",arr_name,"pval:",rankbiaspval)

  #Plot meta-analysis trends for the original pvalues
  fig = plt.figure(figsize=(15,4))
  handles = []

  plt.plot([min_meta, max_meta], -np.log10([np.percentile(min_simmetapvals_arr, 5)]*2), color="black", linestyle="--")
  plt.plot(xaxis_full, -np.log10(original_gcp_pvals), color="black")
  handles.append(mpatches.Patch(color='black', label='Original GCP -log10(pval)'))

  for pvals, metapvals, color, arr_name in zip(pvals_loa, metapvals_loa, loa_colors, loa_names):
    plt.scatter(xaxis_full, -np.log10(pvals[:max_meta]), color=color, s=1)
    plt.plot(xaxis_slice, -np.log10(metapvals[theslice]), color=color)
    handles.append(mpatches.Patch(color=color, label=arr_name))

  plt.xlabel("Event Number (top ranked first)")
  plt.ylabel("-log10 pvalue") #Z-score equivalent derived from inverse-normal-cdf(1-p)
  plt.title(title)
  plt.legend(handles=handles, loc="upper left", ncol=4)
  plt.show()

  return pvalformetapvals_list

print("num permutations:",NUM_PERMUTATIONS)

# %%
spannames = ['test', 'control1', 'control2']#, 'control3', 'control4', 'control5', 'control6']
loa_names = ['Original Timeperiod', '1x before', '1x after']#, '2x before', '2x after', '3x before', '3x after']
loa_colors = ['blue', 'lime', 'salmon']#, 'forestgreen', 'red', 'darkgreen', 'darkred']

all_metatrendplot_pvals = []

windows = ['60', '300', '600', '900']
for signalname, pvals in [('csm1', csm1_psanalysis),
                          ('compositez', compositez_psanalysis)
                          ]:
  print(signalname)
  for metricname in (['pval_maxwindow'+x for x in windows],
                     ['pval_maxabswindow'+x for x in windows]):
    print(metricname)
    pval_for_trendplots_list = make_meta_trend_plot(
      "metric: "+metricname+", timeseries: "+signalname,
      uncorrected_pvals_loa=[np.array([x["pval_"+metricname] for x in pvals[y]])
                             for y in spannames],
      loa_names=loa_names,
      loa_colors=loa_colors)
    for arr_name, pval in zip(loa_names, pval_for_trendplots_list):
      all_metatrendplot_pvals.append( ("span:"+arr_name+"; signal:"+signalname+"; metric:"+metricname,
                                       pval) )

for signalname, pvals in [('csm1', csm1_psanalysis),
                          ('compositez', compositez_psanalysis)
                          ]:
  print(signalname)
  npersegvals = ['NA', '60min']
  for metricname in (['pval_maxwindow'+x for x in windows],
                     ['pval_maxabswindow'+x for x in windows]):
    print("NEGATIVE", metricname)
    pval_for_trendplots_list = make_meta_trend_plot(
      "NEGATIVE metric: "+metricname+", timeseries: "+signalname,
      uncorrected_pvals_loa=[(1-np.array([x["pval_"+metricname] for x in pvals[y]]))
                             for y in spannames],
      loa_names=loa_names,
      loa_colors=loa_colors)
    for arr_name, pval in zip(loa_names, pval_for_trendplots_list):
      all_metatrendplot_pvals.append( ("span:"+arr_name+"; signal:"+signalname+"; metric:"+"negative-"+metricname,
                                       pval) )

# %%
[(x[0], x[1], (x[1]*len(all_metatrendplot_pvals) )/(i+1) )
  for (i,x) in enumerate(sorted(all_metatrendplot_pvals, key=lambda x: x[1]))]
