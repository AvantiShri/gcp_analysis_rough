# %% [markdown]
# <a href="https://colab.research.google.com/github/AvantiShri/gcp_analysis_rough/blob/main/query%20set%20def%20Copy_of_GCP1_heldout_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/GCP_data/all_data
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/GCP_data/all_data

# %%
# !pip uninstall -y gcpdatautils
# !pip install git+https://github.com/AvantiShri/gcpdatautils.git
# Out:
# WARNING: Skipping gcpdatautils as it is not installed.
# Collecting git+https://github.com/AvantiShri/gcpdatautils.git
#   Cloning https://github.com/AvantiShri/gcpdatautils.git to /tmp/pip-req-build-f8x6p1f0
#   Running command git clone --filter=blob:none --quiet https://github.com/AvantiShri/gcpdatautils.git /tmp/pip-req-build-f8x6p1f0
#   Resolved https://github.com/AvantiShri/gcpdatautils.git to commit 6274642ab27e5539a77b452079749596450731d1
#   Preparing metadata (setup.py) ... done
# Collecting bs4 (from gcpdatautils==0.1.0.0)
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.0.0) (3.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.0.0) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.0.0) (1.11.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->gcpdatautils==0.1.0.0) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->gcpdatautils==0.1.0.0) (2.5)
# Building wheels for collected packages: gcpdatautils, bs4
#   Building wheel for gcpdatautils (setup.py) ... done
#   Created wheel for gcpdatautils: filename=gcpdatautils-0.1.0.0-py3-none-any.whl size=6118 sha256=2b0bf1e63d7bafd0cbde2faa3dda58eba22818ba28bbfc8ecdfc831f63ae0229
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ce4qfzdm/wheels/fe/f9/b7/d5afa50c9e111dcf3a66edb57f0c2273e54d108591664596b8
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=b19944b2058ba0682a94593c3d0e6efba94d1306b4db671cf38d2395caf4083b
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built gcpdatautils bs4
# Installing collected packages: bs4, gcpdatautils
# Successfully installed bs4-0.0.1 gcpdatautils-0.1.0.0

# %%
# !mkdir analysis
# Out:
# mkdir: cannot create directory ‘analysis’: File exists

# %%
import numpy as np
from collections import defaultdict
import h5py
from datetime import datetime, timedelta
from gcpdatautils import GCPMissingDataError, ROTTEN_EGGS, parse_rotten_egg_file

class GCPHdf5DataReader(object):

  def __init__(self, bad_data_file=ROTTEN_EGGS,
                     year_to_hdf5path=lambda x: "GCP1data_"+str(x)+".hdf5"):
    print("Parsing the bad data file:",bad_data_file)
    #reorganize the bad data list by device ID
    self.bad_data_lookup = defaultdict(list)
    for baddata_starttime, baddata_endtime, deviceid in parse_rotten_egg_file(bad_data_file):
      self.bad_data_lookup[deviceid].append((baddata_starttime, baddata_endtime))
    self.year_to_hdf5fh = {} #mapping from the year to the hdf5 file handle
    self.year_to_hdf5path = year_to_hdf5path

  def fetch_data(self, starttime, endtime, normalize=False):

    if (endtime.strftime("%Y-%m-%d") == starttime.strftime("%Y-%m-%d")):
      return self.fetch_data_within_day_normalize(starttime, endtime, normalize=normalize) #returns both data and devices
    else:
      #split into accesses over multiple days
      start_day = starttime.strftime("%Y-%m-%d")
      end_day = endtime.strftime("%Y-%m-%d")
      #for the first day:
      day_accesses = [ (
          starttime,
          datetime.strptime(start_day+" 23:59:59", '%Y-%m-%d %H:%M:%S')) ]
      #for intermediate days:
      dayoffset = 1
      inter_day = (starttime + timedelta(days=dayoffset)).strftime("%Y-%m-%d")
      while inter_day != end_day:
        day_accesses.append(
            (datetime.strptime(inter_day+" 00:00:00", '%Y-%m-%d %H:%M:%S'),
             datetime.strptime(inter_day+" 23:59:59", '%Y-%m-%d %H:%M:%S')))
        dayoffset += 1
        inter_day = (starttime + timedelta(days=dayoffset)).strftime("%Y-%m-%d")

      #for the final day
      day_accesses.append(
          (datetime.strptime(inter_day+" 00:00:00", '%Y-%m-%d %H:%M:%S'),
           endtime))
      days_data_and_devices = [self.fetch_data_within_day_normalize(t1, t2, normalize=normalize) for (t1,t2) in day_accesses]
      #if all the days have the same sets of devices...
      if (len(set([str(x[1]) for x in days_data_and_devices]))==1):
        return np.concatenate([x[0] for x in days_data_and_devices], axis=0), days_data_and_devices[0][1]
      else:
        #print("Some days don't have same devices. Rearranging")
        all_devices = set()
        [all_devices.update(x[1]) for x in days_data_and_devices]
        all_devices = sorted(all_devices)
        all_devices_newidxs = dict([(x[1],x[0]) for x in enumerate(all_devices)])
        rearranged_days_data = []
        for day_data, day_devices in days_data_and_devices:
          rearranged_day_data = np.zeros((len(day_data), len(all_devices)))
          rearranged_day_data[:,:] = np.nan
          for orig_deviceidx, deviceid in enumerate(day_devices):
            rearranged_day_data[:,all_devices_newidxs[deviceid]] = day_data[:,orig_deviceidx]
          rearranged_days_data.append(rearranged_day_data)
        return np.concatenate(rearranged_days_data, axis=0), all_devices

  def fetch_data_within_day_normalize(self, starttime, endtime, normalize):
    if (normalize==False):
      return self.fetch_data_within_day(starttime, endtime)
    else:
      day = starttime.strftime("%Y-%m-%d")
      day_start = datetime.strptime(day+" 00:00:00", '%Y-%m-%d %H:%M:%S')
      day_end = datetime.strptime(day+" 23:59:59", '%Y-%m-%d %H:%M:%S')
      full_day_data, daydevices = self.fetch_data_within_day(day_start, day_end)
      #set ddof=1 to get unbiased (more conservative) stdev estimates
      device_day_stdevs = np.nan_to_num(np.nanstd(full_day_data, axis=0, ddof=1), np.sqrt(50))
      device_day_means = np.nan_to_num(np.nanmean(full_day_data, axis=0), 100)
      #transform the data to be centered around 100, with stdev of sqrt(50)
      full_day_data_normalized = ((full_day_data - device_day_means[None,:])/
                                  (device_day_stdevs[None,:]/np.sqrt(50))) + 100
      start_offset =  int(starttime.timestamp() - day_start.timestamp())
      end_offset = int((endtime.timestamp() - day_start.timestamp()) + 1)
      return full_day_data_normalized[start_offset:end_offset], daydevices

  def get_fh_for_year(self, year):
    if (year not in self.year_to_hdf5fh):
      self.year_to_hdf5fh[year] = h5py.File(self.year_to_hdf5path(year), "r")
    return self.year_to_hdf5fh[year]

  def get_available_days_in_year(self, year):
    fh = self.get_fh_for_year(year)
    return fh.keys()

  def fetch_data_within_day(self, starttime, endtime):
    assert endtime.strftime("%Y-%m-%d") == starttime.strftime("%Y-%m-%d")
    year = starttime.year
    fh = self.get_fh_for_year(year)
    day = starttime.strftime("%Y-%m-%d")
    if (day not in fh):
      raise GCPMissingDataError("data for "+day+" not present")
    dset = fh[day]
    if dset.attrs['start_time'] > starttime.timestamp():
      raise GCPMissingDataError("query for day "
             +day+" starts at "+str(starttime.timestamp())
             +" but data for day starts at "+str(dset.attrs['start_time']))
    if dset.attrs['end_time'] < endtime.timestamp():
      raise GCPMissingDataError("query for day "
             +day+" ends at "+str(endtime.timestamp())
             +" but data for day ends at "+str(dset.attrs['end_time']))
    #now that we have verified that the day has all the data we need...
    start_offset = int(starttime.timestamp() - dset.attrs['start_time'])
    end_offset = int(endtime.timestamp()+1 - dset.attrs['start_time']) #add +1 since GCP ranges are end-inclusive
    day_data = np.array(dset[start_offset:end_offset]).astype("float")
    #replace 255 with nan
    day_data[day_data==255] = np.nan
    #Radin 2023 (Anomalous entropic effects in physical systems associated
    # with collective consciousness) said "All individual samples within a matrix
    # less than 55 or greater than 145 were set to nan" so we do that here
    day_data = np.where((day_data < 55), np.nan, day_data)
    day_data = np.where((day_data > 145), np.nan, day_data)

    #Mask out columns with bad data
    masking_occurred = False
    devices_on_day = fh[day].attrs["device_ids"]
    for deviceid_idx,deviceid in enumerate(devices_on_day):
      if (deviceid in self.bad_data_lookup):
        for rottenegg_start, rottenegg_end in self.bad_data_lookup[deviceid]:
          if (rottenegg_start.timestamp() <= endtime.timestamp() and rottenegg_end.timestamp() >= starttime.timestamp()):
            if (masking_occurred == False):
              print("Before masking, fraction of nans in raw data is", np.mean(np.isnan(day_data)),"for",starttime,"to",endtime)
            masking_occurred = True
            print("Found 'rotten egg' entries for device id:",deviceid,
                  "in time range",starttime,"to",endtime,
                  "(range:",rottenegg_start,"to",rottenegg_end,")")
            mask_startidx = int(max(rottenegg_start.timestamp()-starttime.timestamp(),0))
            mask_endidx = int(min((rottenegg_end.timestamp()+1)-starttime.timestamp(), len(day_data))) #+1 because end inclusive
            day_data[mask_startidx:mask_endidx, deviceid_idx] = np.nan

    if (masking_occurred):
      print("After masking, fraction of nans in raw data is", np.mean(np.isnan(day_data)))
    #Check that there are no rows that completely lack data
    nonnan_devices_per_second = np.sum(np.isnan(day_data)==False, axis=1)
    if (np.min(nonnan_devices_per_second)==0):
      raise GCPMissingDataError("Some seconds for query from "+str(starttime)+" to "+str(endtime)+" had no data")

    return day_data, devices_on_day

  def __exit__(self, exc_type, exc_value, traceback):
    self.close()

  def close(self):
    for fh in self.year_to_hdf5fh.values():
      fh.close()

gcp_data_reader = GCPHdf5DataReader()
# Out:
# Parsing the bad data file: /usr/local/lib/python3.10/dist-packages/gcpdatautils/resources/rotteneggs.txt
# manually correcting 47,2000-01-01 00:00:00,2001-06-31 23:59:59,2222
# manually correcting 47,2008-04-25 00:00:00,2008-04-55 23:59:59,1092

# %%
#for a given year
#iterate through days in the year
#for each day
#read in the *normalized* data
#do the splits
#compute the stats for non-overlapping 1 min blocks
#append to a new array with start & end info

import h5py
from datetime import datetime, timedelta
import numpy as np
import scipy

def compute_composite_zscores(data):
  composite_zs = np.nansum((data-100)/np.sqrt(50),axis=1)/np.sqrt(
        np.sum(np.isnan(data)==False, axis=1))
  return composite_zs

def compute_zscore_for_chisquared_test(data):
  return scipy.stats.norm.ppf(scipy.stats.chi2.cdf(
            np.sum(np.square(
                compute_composite_zscores(data))), len(data)))

def indices_to_binaryflagrep(indices):
  result = 0
  for idx in indices:
    result += 1 << idx
  return result

MINDEVICES = 10
SEED = 1234
SPANLENGTH = 60 #specify span in seconds
QUERY_THRESHOLD = 1 #if query score is above this, heldout scores will be retained for analysis

assert (24*60*60)%SPANLENGTH == 0 #assert span divides day

cumulative_heldout_z_passing_threshold = 0
n_for_stouffers_z = 0

for year in range(1998,2023):
#for year in range(2007,2023):

  rng = np.random.RandomState(SEED)

  all_query_stats_chisqtoz = []
  all_heldout_stats_chisqtoz = []
  span_start_timestamps = []
  query_deviceflags = []
  heldout_deviceflags = []

  available_days = gcp_data_reader.get_available_days_in_year(year)

  for day in available_days:
    print("On day",day)
    day_start = datetime.strptime(day+" 00:00:00", '%Y-%m-%d %H:%M:%S')
    day_end = datetime.strptime(day+" 23:59:59", '%Y-%m-%d %H:%M:%S')
    try:
      full_day_data, day_devices = gcp_data_reader.fetch_data_within_day_normalize(
          day_start, day_end, normalize=True)
      if (len(full_day_data) < 60*60*24):
        continue #skip incomplete days
      else:
        for span_idx in range(int(60*60*24/SPANLENGTH)):
          span_data = full_day_data[span_idx*SPANLENGTH : (span_idx+1)*SPANLENGTH]
          nanfrac = np.mean(np.isnan(span_data),axis=0)
          deviceindices_with_full_data = np.arange(len(day_devices))[nanfrac==0.0]
          #Only do the split when there's a reasonably large num of non-nan devices for the span
          if (len(deviceindices_with_full_data) >= MINDEVICES):
            #do a random permutation of device indices
            shuffled_device_indices = rng.permutation(deviceindices_with_full_data)
            #take the first half (rounding up) as the 'query' and the other have as eval
            num_in_query_set = int(np.ceil(len(shuffled_device_indices)/2.0))
            query_device_indices = shuffled_device_indices[:num_in_query_set]
            heldout_device_indices = shuffled_device_indices[num_in_query_set:]
            query_data = span_data[:, query_device_indices]
            heldout_data = span_data[:, heldout_device_indices]
            query_stats_chisqtoz = compute_zscore_for_chisquared_test(query_data)
            heldout_data_chisqtoz = compute_zscore_for_chisquared_test(heldout_data)
            query_devices_flagrep = indices_to_binaryflagrep(query_device_indices)
            heldout_devices_flagrep = indices_to_binaryflagrep(heldout_device_indices)
            all_devices_flagrep = indices_to_binaryflagrep(deviceindices_with_full_data)
            assert (query_devices_flagrep & heldout_devices_flagrep) == 0
            assert (query_devices_flagrep | heldout_devices_flagrep) == all_devices_flagrep
            #store the stats
            span_start_timestamp = (day_start + timedelta(seconds=span_idx*SPANLENGTH)).timestamp()
            all_query_stats_chisqtoz.append(query_stats_chisqtoz)
            all_heldout_stats_chisqtoz.append(heldout_data_chisqtoz)
            span_start_timestamps.append(span_start_timestamp)
            query_deviceflags.append(query_devices_flagrep)
            heldout_deviceflags.append(heldout_devices_flagrep)
            if (query_stats_chisqtoz > QUERY_THRESHOLD):
              cumulative_heldout_z_passing_threshold += heldout_data_chisqtoz
              n_for_stouffers_z += 1
    except GCPMissingDataError as e:
      print("MISSING DATA ERROR!",e)
    if (n_for_stouffers_z > 0):
      print("Heldout Stouffer's Z (n="+str(n_for_stouffers_z)+")",
          cumulative_heldout_z_passing_threshold/np.sqrt(n_for_stouffers_z))

  #save the results for the year
  np.save("analysis/"+str(year)+"_"+str(SPANLENGTH)+"_all_query_stats_chisqtoz.npy",
          np.array(all_query_stats_chisqtoz))
  np.save("analysis/"+str(year)+"_"+str(SPANLENGTH)+"_all_heldout_stats_chisqtoz.npy",
          np.array(all_heldout_stats_chisqtoz))
  np.save("analysis/"+str(year)+"_"+str(SPANLENGTH)+"_span_start_timestamps.npy",
          np.array(span_start_timestamps))
  np.save("analysis/"+str(year)+"_"+str(SPANLENGTH)+"_query_deviceflags.npy",
          np.array(query_deviceflags))
  np.save("analysis/"+str(year)+"_"+str(SPANLENGTH)+"_heldout_deviceflags.npy",
          np.array(heldout_deviceflags))
# Out:
# On day 1998-08-05
# On day 1998-08-06
# On day 1998-08-07
# On day 1998-08-08
# On day 1998-08-09
# On day 1998-08-10
# On day 1998-08-11
# On day 1998-08-12
# On day 1998-08-13
# On day 1998-08-14
# MISSING DATA ERROR! query for day 1998-08-14 starts at 903052800.0 but data for day starts at 903052830
# On day 1998-08-15
# MISSING DATA ERROR! Some seconds for query from 1998-08-15 00:00:00 to 1998-08-15 23:59:59 had no data
# On day 1998-08-16
# MISSING DATA ERROR! Some seconds for query from 1998-08-16 00:00:00 to 1998-08-16 23:59:59 had no data
# On day 1998-08-17
# MISSING DATA ERROR! Some seconds for query from 1998-08-17 00:00:00 to 1998-08-17 23:59:59 had no data
# On day 1998-08-18
# MISSING DATA ERROR! Some seconds for query from 1998-08-18 00:00:00 to 1998-08-18 23:59:59 had no data
# On day 1998-08-19
# MISSING DATA ERROR! Some seconds for query from 1998-08-19 00:00:00 to 1998-08-19 23:59:59 had no data
# On day 1998-08-20
# On day 1998-08-21
# On day 1998-08-22
# On day 1998-08-23
# MISSING DATA ERROR! Some seconds for query from 1998-08-23 00:00:00 to 1998-08-23 23:59:59 had no data
# On day 1998-08-24
# On day 1998-08-25
# MISSING DATA ERROR! Some seconds for query from 1998-08-25 00:00:00 to 1998-08-25 23:59:59 had no data
# On day 1998-08-26
# MISSING DATA ERROR! Some seconds for query from 1998-08-26 00:00:00 to 1998-08-26 23:59:59 had no data
# On day 1998-08-27
# MISSING DATA ERROR! Some seconds for query from 1998-08-27 00:00:00 to 1998-08-27 23:59:59 had no data
# On day 1998-08-28
# On day 1998-08-29
# On day 1998-08-30
# On day 1998-08-31
# MISSING DATA ERROR! Some seconds for query from 1998-08-31 00:00:00 to 1998-08-31 23:59:59 had no data
# On day 1998-09-01
# On day 1998-09-02
# On day 1998-09-03
# On day 1998-09-04
# On day 1998-09-05
# MISSING DATA ERROR! Some seconds for query from 1998-09-05 00:00:00 to 1998-09-05 23:59:59 had no data
# On day 1998-09-06
# MISSING DATA ERROR! query for day 1998-09-06 starts at 905040000.0 but data for day starts at 905119200
# On day 1998-09-07
# On day 1998-09-08
# On day 1998-09-09
# On day 1998-09-10
# On day 1998-09-11
# On day 1998-09-12
# On day 1998-09-13
# On day 1998-09-14
# On day 1998-09-15
# On day 1998-09-16
# On day 1998-09-17
# On day 1998-09-18
# On day 1998-09-19
# On day 1998-09-20
# On day 1998-09-21
# On day 1998-09-22
# On day 1998-09-23
# On day 1998-09-24
# On day 1998-09-25
# On day 1998-09-26
# On day 1998-09-27
# On day 1998-09-28
# On day 1998-09-29
# On day 1998-09-30
# On day 1998-10-01
# On day 1998-10-02
# On day 1998-10-03
# On day 1998-10-04
# On day 1998-10-05
# On day 1998-10-06
# On day 1998-10-07
# On day 1998-10-08
# On day 1998-10-09
# On day 1998-10-10
# On day 1998-10-11
# On day 1998-10-12
# On day 1998-10-13
# On day 1998-10-14
# On day 1998-10-15
# On day 1998-10-16
# On day 1998-10-17
# On day 1998-10-18
# On day 1998-10-19
# On day 1998-10-20
# MISSING DATA ERROR! query for day 1998-10-20 ends at 908927999.0 but data for day ends at 908905919
# On day 1998-10-21
# On day 1998-10-22
# On day 1998-10-23
# On day 1998-10-24
# On day 1998-10-25
# On day 1998-10-26
# On day 1998-10-27
# On day 1998-10-28
# On day 1998-10-29
# On day 1998-10-30
# On day 1998-10-31
# On day 1998-11-01
# On day 1998-11-02
# On day 1998-11-03
# On day 1998-11-04
# On day 1998-11-05
# On day 1998-11-06
# On day 1998-11-07
# On day 1998-11-08
# On day 1998-11-09
# On day 1998-11-10
# On day 1998-11-11
# On day 1998-11-12
# On day 1998-11-13
# On day 1998-11-14
# <ipython-input-7-067d6b8ab326>:74: RuntimeWarning: Mean of empty slice
#   device_day_means = np.nan_to_num(np.nanmean(full_day_data, axis=0), 100)
# On day 1998-11-15
# On day 1998-11-16
# On day 1998-11-17
# On day 1998-11-18
# On day 1998-11-19
# On day 1998-11-20
# On day 1998-11-21
# On day 1998-11-22
# On day 1998-11-23
# On day 1998-11-24
# On day 1998-11-25
# On day 1998-11-26
# On day 1998-11-27
# On day 1998-11-28
# On day 1998-11-29
# On day 1998-11-30
# On day 1998-12-01
# On day 1998-12-02
# On day 1998-12-03
# On day 1998-12-04
# On day 1998-12-05
# On day 1998-12-06
# On day 1998-12-07
# On day 1998-12-08
# On day 1998-12-09
# On day 1998-12-10
# Before masking, fraction of nans in raw data is 0.15488095238095237 for 1998-12-10 00:00:00 to 1998-12-10 23:59:59
# Found 'rotten egg' entries for device id: 1005 in time range 1998-12-10 00:00:00 to 1998-12-10 23:59:59 (range: 1998-12-10 00:00:00 to 1998-12-17 23:59:59 )
# After masking, fraction of nans in raw data is 0.15585482804232803
# On day 1998-12-11
# Before masking, fraction of nans in raw data is 4.96031746031746e-06 for 1998-12-11 00:00:00 to 1998-12-11 23:59:59
# Found 'rotten egg' entries for device id: 1005 in time range 1998-12-11 00:00:00 to 1998-12-11 23:59:59 (range: 1998-12-10 00:00:00 to 1998-12-17 23:59:59 )
# After masking, fraction of nans in raw data is 0.14286210317460318
# On day 1998-12-12
# Before masking, fraction of nans in raw data is 0.024657738095238094 for 1998-12-12 00:00:00 to 1998-12-12 23:59:59
# Found 'rotten egg' entries for device id: 1005 in time range 1998-12-12 00:00:00 to 1998-12-12 23:59:59 (range: 1998-12-10 00:00:00 to 1998-12-17 23:59:59 )
# After masking, fraction of nans in raw data is 0.1428587962962963
# On day 1998-12-13
# Before masking, fraction of nans in raw data is 0.1367989417989418 for 1998-12-13 00:00:00 to 1998-12-13 23:59:59
# Found 'rotten egg' entries for device id: 1005 in time range 1998-12-13 00:00:00 to 1998-12-13 23:59:59 (range: 1998-12-10 00:00:00 to 1998-12-17 23:59:59 )
# After masking, fraction of nans in raw data is 0.14286044973544973
# On day 1998-12-14
# Before masking, fraction of nans in raw data is 0.13672784391534393 for 1998-12-14 00:00:00 to 1998-12-14 23:59:59
# Found 'rotten egg' entries for device id: 1005 in time range 1998-12-14 00:00:00 to 1998-12-14 23:59:59 (range: 1998-12-10 00:00:00 to 1998-12-17 23:59:59 )
# After masking, fraction of nans in raw data is 0.1428587962962963
# On day 1998-12-15
# Before masking, fraction of nans in raw data is 0.1367824074074074 for 1998-12-15 00:00:00 to 1998-12-15 23:59:59
# Found 'rotten egg' entries for device id: 1005 in time range 1998-12-15 00:00:00 to 1998-12-15 23:59:59 (range: 1998-12-10 00:00:00 to 1998-12-17 23:59:59 )
# After masking, fraction of nans in raw data is 0.14286044973544973
# On day 1998-12-16
# Before masking, fraction of nans in raw data is 0.029133597883597883 for 1998-12-16 00:00:00 to 1998-12-16 23:59:59
# Found 'rotten egg' entries for device id: 1005 in time range 1998-12-16 00:00:00 to 1998-12-16 23:59:59 (range: 1998-12-10 00:00:00 to 1998-12-17 23:59:59 )
# After masking, fraction of nans in raw data is 0.14286044973544973
# On day 1998-12-17
# Before masking, fraction of nans in raw data is 1.6534391534391535e-06 for 1998-12-17 00:00:00 to 1998-12-17 23:59:59
# Found 'rotten egg' entries for device id: 1005 in time range 1998-12-17 00:00:00 to 1998-12-17 23:59:59 (range: 1998-12-10 00:00:00 to 1998-12-17 23:59:59 )
# After masking, fraction of nans in raw data is 0.1428587962962963
# On day 1998-12-18
# On day 1998-12-19
# On day 1998-12-20
# On day 1998-12-21
# On day 1998-12-22
# On day 1998-12-23
# On day 1998-12-24
# On day 1998-12-25
# On day 1998-12-26
# On day 1998-12-27
# On day 1998-12-28
# On day 1998-12-29
# On day 1998-12-30
# On day 1998-12-31
# On day 1999-01-01
# On day 1999-01-02
# On day 1999-01-03
# On day 1999-01-04
# On day 1999-01-05
# On day 1999-01-06
# On day 1999-01-07
# On day 1999-01-08
# On day 1999-01-09
# On day 1999-01-10
# On day 1999-01-11
# On day 1999-01-12
# On day 1999-01-13
# On day 1999-01-14
# On day 1999-01-15
# On day 1999-01-16
# On day 1999-01-17
# On day 1999-01-18
# On day 1999-01-19
# On day 1999-01-20
# On day 1999-01-21
# On day 1999-01-22
# On day 1999-01-23
# On day 1999-01-24
# On day 1999-01-25
# On day 1999-01-26
# On day 1999-01-27
# On day 1999-01-28
# On day 1999-01-29
# On day 1999-01-30
# On day 1999-01-31
# On day 1999-02-01
# Heldout Stouffer's Z (n=15) 0.19825782876105202
# On day 1999-02-02
# Heldout Stouffer's Z (n=135) 0.560348401074565
# On day 1999-02-03
# Heldout Stouffer's Z (n=135) 0.560348401074565
# On day 1999-02-04
# Heldout Stouffer's Z (n=289) -1.0079910434459067
# On day 1999-02-05
# Heldout Stouffer's Z (n=505) -0.7836031234440441
# On day 1999-02-06
# Heldout Stouffer's Z (n=727) -0.5586814423838852
# On day 1999-02-07
# Heldout Stouffer's Z (n=947) 0.1746780946240218
# On day 1999-02-08
# Heldout Stouffer's Z (n=1167) 0.2298326915210665
# On day 1999-02-09
# Heldout Stouffer's Z (n=1391) 0.023876882371374978
# On day 1999-02-10
# Heldout Stouffer's Z (n=1620) -0.15924653244336184
# On day 1999-02-11
# Heldout Stouffer's Z (n=1851) 0.3426344241999024
# On day 1999-02-12
# Heldout Stouffer's Z (n=2099) -0.07700392035018565
# On day 1999-02-13
# Heldout Stouffer's Z (n=2322) 0.21234109990181924
# On day 1999-02-14
# Heldout Stouffer's Z (n=2569) 0.08322462091635001
# On day 1999-02-15
# Heldout Stouffer's Z (n=2766) -0.07502766683654283
# On day 1999-02-16
# Heldout Stouffer's Z (n=2979) -0.20179234078079825
# On day 1999-02-17
# Heldout Stouffer's Z (n=3213) -0.3786176866505299
# On day 1999-02-18
# Heldout Stouffer's Z (n=3441) -0.4288979786757745
# On day 1999-02-19
# Heldout Stouffer's Z (n=3665) -0.49011808647139304
# On day 1999-02-20
# Heldout Stouffer's Z (n=3900) -0.5810528216261469
# On day 1999-02-21
# Heldout Stouffer's Z (n=4118) -0.7140032493880454
# On day 1999-02-22
# Heldout Stouffer's Z (n=4341) -0.6251834926274346
# On day 1999-02-23
# Heldout Stouffer's Z (n=4569) -0.20760516483444025
# On day 1999-02-24
# Heldout Stouffer's Z (n=4774) -0.18223809986946857
# On day 1999-02-25
# Heldout Stouffer's Z (n=4880) -0.3080778101823977
# On day 1999-02-26
# Heldout Stouffer's Z (n=4880) -0.3080778101823977
# On day 1999-02-27
# Heldout Stouffer's Z (n=4961) -0.29275400004612456
# On day 1999-02-28
# Heldout Stouffer's Z (n=5194) -0.26692946263206774
# On day 1999-03-01
# Heldout Stouffer's Z (n=5308) -0.10330951366261908
# On day 1999-03-02
# Heldout Stouffer's Z (n=5308) -0.10330951366261908
# On day 1999-03-03
# Heldout Stouffer's Z (n=5308) -0.10330951366261908
# On day 1999-03-04
# Heldout Stouffer's Z (n=5327) -0.13153105112829191
# On day 1999-03-05
# Heldout Stouffer's Z (n=5570) -0.09873326466215834
# On day 1999-03-06
# Heldout Stouffer's Z (n=5795) 0.03385922094659885
# On day 1999-03-07
# Heldout Stouffer's Z (n=5843) 0.1117240432646115
# On day 1999-03-08
# Heldout Stouffer's Z (n=5905) 0.08431554090802064
# On day 1999-03-09
# Heldout Stouffer's Z (n=6121) 0.1401896539952741
# On day 1999-03-10
# Heldout Stouffer's Z (n=6351) 0.46430551192548297
# On day 1999-03-11
# Heldout Stouffer's Z (n=6580) 0.7766669791544294
# On day 1999-03-12
# Heldout Stouffer's Z (n=6823) 0.9737438094664926
# On day 1999-03-13
# Heldout Stouffer's Z (n=7035) 0.9931740092470865
# On day 1999-03-14
# Heldout Stouffer's Z (n=7249) 1.165588629313628
# On day 1999-03-15
# Heldout Stouffer's Z (n=7495) 1.510236027808356
# On day 1999-03-16
# Heldout Stouffer's Z (n=7715) 1.3101085219669328
# On day 1999-03-17
# Heldout Stouffer's Z (n=7941) 1.4398268665851466
# On day 1999-03-18
# Heldout Stouffer's Z (n=8181) 1.6238066156302529
# On day 1999-03-19
# Heldout Stouffer's Z (n=8414) 1.4451927137946354
# On day 1999-03-20
# Heldout Stouffer's Z (n=8625) 1.5287784285596013
# On day 1999-03-21
# Heldout Stouffer's Z (n=8867) 1.4570105373389568
# On day 1999-03-22
# Heldout Stouffer's Z (n=9081) 1.3008210573827235
# On day 1999-03-23
# Heldout Stouffer's Z (n=9319) 1.401247062909735
# On day 1999-03-24
# Heldout Stouffer's Z (n=9553) 1.0434306647414224
# On day 1999-03-25
# Heldout Stouffer's Z (n=9790) 1.1153977650773503
# On day 1999-03-26
# Heldout Stouffer's Z (n=10009) 1.12587332313351
# On day 1999-03-27
# Heldout Stouffer's Z (n=10214) 1.3252404789684795
# On day 1999-03-28
# Heldout Stouffer's Z (n=10432) 1.4277518203752904
# On day 1999-03-29
# Heldout Stouffer's Z (n=10677) 1.2396894210054084
# On day 1999-03-30
# Heldout Stouffer's Z (n=10905) 1.3015420809942675
# On day 1999-03-31
# Heldout Stouffer's Z (n=11139) 1.2094117683533852
# On day 1999-04-01
# Heldout Stouffer's Z (n=11375) 1.3566978990576886
# On day 1999-04-02
# Heldout Stouffer's Z (n=11616) 1.3113540204720966
# On day 1999-04-03
# Heldout Stouffer's Z (n=11844) 1.5102624241661389
# On day 1999-04-04
# Heldout Stouffer's Z (n=12069) 1.3307617365253526
# On day 1999-04-05
# Heldout Stouffer's Z (n=12299) 1.2959844323789504
# On day 1999-04-06
# Heldout Stouffer's Z (n=12528) 1.3409666433555705
# On day 1999-04-07
# Heldout Stouffer's Z (n=12750) 1.3913259538254434
# On day 1999-04-08
# Heldout Stouffer's Z (n=12986) 1.6591950833403397
# On day 1999-04-09
# Heldout Stouffer's Z (n=13225) 1.6983899119992627
# On day 1999-04-10
# Heldout Stouffer's Z (n=13449) 1.743343760683758
# On day 1999-04-11
# Heldout Stouffer's Z (n=13671) 1.8299881396493485
# On day 1999-04-12
# Heldout Stouffer's Z (n=13901) 1.711841818375401
# On day 1999-04-13
# Heldout Stouffer's Z (n=14116) 1.6622063590518885
# On day 1999-04-14
# Heldout Stouffer's Z (n=14312) 1.8690656297454824
# On day 1999-04-15
# Heldout Stouffer's Z (n=14521) 1.9438875783751486
# On day 1999-04-16
# Heldout Stouffer's Z (n=14775) 1.90036717264504
# On day 1999-04-17
# Heldout Stouffer's Z (n=14982) 2.0354875536649426
# On day 1999-04-18
# Heldout Stouffer's Z (n=15200) 1.9713428965440285
# On day 1999-04-19
# Heldout Stouffer's Z (n=15406) 2.096891588874005
# On day 1999-04-20
# Heldout Stouffer's Z (n=15616) 1.8801204381331142
# On day 1999-04-21
# Heldout Stouffer's Z (n=15852) 1.7345738737384662
# On day 1999-04-22
# Heldout Stouffer's Z (n=16061) 1.6567829225307418
# On day 1999-04-23
# Heldout Stouffer's Z (n=16300) 1.8405607321417217
# On day 1999-04-24
# Heldout Stouffer's Z (n=16529) 1.7298645794771106
# On day 1999-04-25
# Heldout Stouffer's Z (n=16645) 1.6720607416953737
# On day 1999-04-26
# Heldout Stouffer's Z (n=16809) 1.5433253668411138
# On day 1999-04-27
# Heldout Stouffer's Z (n=17032) 1.4510856392406417
# On day 1999-04-28
# Heldout Stouffer's Z (n=17270) 1.4857016067996769
# On day 1999-04-29
# Heldout Stouffer's Z (n=17516) 1.5151449186556833
# On day 1999-04-30
# Heldout Stouffer's Z (n=17741) 1.7064719241129032
# On day 1999-05-01
# Heldout Stouffer's Z (n=17947) 1.7228533826578192
# On day 1999-05-02
# Heldout Stouffer's Z (n=18162) 1.81184759221021
# On day 1999-05-03
# Heldout Stouffer's Z (n=18380) 1.7981945148615461
# On day 1999-05-04
# Heldout Stouffer's Z (n=18610) 1.849495671459778
# On day 1999-05-05
# Heldout Stouffer's Z (n=18833) 1.8606359866951074
# On day 1999-05-06
# Heldout Stouffer's Z (n=19078) 1.979193606452005
# On day 1999-05-07
# Heldout Stouffer's Z (n=19318) 2.13654760319415
# On day 1999-05-08
# Heldout Stouffer's Z (n=19561) 1.9981520449546262
# On day 1999-05-09
# Heldout Stouffer's Z (n=19760) 1.8614863735098743
# On day 1999-05-10
# Heldout Stouffer's Z (n=19980) 1.6579111892463692
# On day 1999-05-11
# Heldout Stouffer's Z (n=19980) 1.6579111892463692
# On day 1999-05-12
# Heldout Stouffer's Z (n=20230) 1.6578786307433109
# On day 1999-05-13
# Heldout Stouffer's Z (n=20474) 1.5750721487172457
# On day 1999-05-14
# Heldout Stouffer's Z (n=20728) 1.6067459049457635
# On day 1999-05-15
# Heldout Stouffer's Z (n=20938) 1.7315937221889444
# On day 1999-05-16
# Heldout Stouffer's Z (n=21182) 1.6247964859717026
# On day 1999-05-17
# Heldout Stouffer's Z (n=21436) 1.5969439327352026
# On day 1999-05-18
# Heldout Stouffer's Z (n=21660) 1.5786752137654558
# On day 1999-05-19
# Heldout Stouffer's Z (n=21910) 1.582015977326706
# On day 1999-05-20
# Heldout Stouffer's Z (n=22129) 1.5663588461145737
# On day 1999-05-21
# Heldout Stouffer's Z (n=22368) 1.7520193899481729
# On day 1999-05-22
# Heldout Stouffer's Z (n=22591) 1.7981033469691576
# On day 1999-05-23
# Heldout Stouffer's Z (n=22832) 1.8165127573992115
# On day 1999-05-24
# Heldout Stouffer's Z (n=23095) 1.6099591116703516
# On day 1999-05-25
# Heldout Stouffer's Z (n=23310) 1.6143984825914326
# On day 1999-05-26
# Heldout Stouffer's Z (n=23544) 1.7193351776469337
# On day 1999-05-27
# Heldout Stouffer's Z (n=23786) 1.6465826780131432
# On day 1999-05-28
# Heldout Stouffer's Z (n=24015) 1.6735579040721578
# On day 1999-05-29
# Heldout Stouffer's Z (n=24216) 1.6939612457610211
# On day 1999-05-30
# Heldout Stouffer's Z (n=24417) 1.723729311142183
# On day 1999-05-31
# Heldout Stouffer's Z (n=24660) 1.646698713917065
# On day 1999-06-01
# Heldout Stouffer's Z (n=24898) 1.6350582436519754
# On day 1999-06-02
# Heldout Stouffer's Z (n=25118) 1.6551846851113268
# On day 1999-06-03
# Heldout Stouffer's Z (n=25367) 1.6384061589229408
# On day 1999-06-04
# Heldout Stouffer's Z (n=25583) 1.6677241654390338
# On day 1999-06-05
# Heldout Stouffer's Z (n=25821) 1.642029307468466
# On day 1999-06-06
# Heldout Stouffer's Z (n=26053) 1.6880163947341635
# On day 1999-06-07
# Heldout Stouffer's Z (n=26314) 1.8399510471273726
# On day 1999-06-08
# Heldout Stouffer's Z (n=26547) 1.9053261762203633
# On day 1999-06-09
# Heldout Stouffer's Z (n=26791) 1.8411268836251338
# On day 1999-06-10
# Heldout Stouffer's Z (n=27003) 1.835933724509446
# On day 1999-06-11
# Heldout Stouffer's Z (n=27233) 1.7958024906328582
# On day 1999-06-12
# Heldout Stouffer's Z (n=27455) 1.7924833685996175
# On day 1999-06-13
# Heldout Stouffer's Z (n=27662) 1.862463964738197
# On day 1999-06-14
# Heldout Stouffer's Z (n=27878) 1.9265640459076947
# On day 1999-06-15
# Heldout Stouffer's Z (n=28095) 2.0199962590269194
# On day 1999-06-16
# Heldout Stouffer's Z (n=28322) 2.0028328530321815
# On day 1999-06-17
# Heldout Stouffer's Z (n=28563) 2.092848319698325
# On day 1999-06-18
# Heldout Stouffer's Z (n=28809) 2.254265891165813
# On day 1999-06-19
# Heldout Stouffer's Z (n=29041) 2.285496562374493
# On day 1999-06-20
# Heldout Stouffer's Z (n=29269) 2.1633869443247096
# On day 1999-06-21
# Heldout Stouffer's Z (n=29522) 2.1609367458440163
# On day 1999-06-22
# Heldout Stouffer's Z (n=29728) 2.26083208043561
# On day 1999-06-23
# Heldout Stouffer's Z (n=29977) 2.2007005276921676
# On day 1999-06-24
# Heldout Stouffer's Z (n=30243) 2.2561855172239476
# On day 1999-06-25
# Heldout Stouffer's Z (n=30477) 2.2049293295110544
# On day 1999-06-26
# Heldout Stouffer's Z (n=30717) 2.2925029724363917
# On day 1999-06-27
# Heldout Stouffer's Z (n=30931) 2.1715504923220976
# On day 1999-06-28
# Heldout Stouffer's Z (n=31159) 2.226229209457642
# On day 1999-06-29
# Heldout Stouffer's Z (n=31392) 2.214537244341766
# On day 1999-06-30
# Heldout Stouffer's Z (n=31644) 2.2698466167117366
# On day 1999-07-01
# Heldout Stouffer's Z (n=31868) 2.4272532196319245
# On day 1999-07-02
# Heldout Stouffer's Z (n=32083) 2.54884303338298
# On day 1999-07-03
# Heldout Stouffer's Z (n=32310) 2.4877897642060347
# On day 1999-07-04
# Heldout Stouffer's Z (n=32542) 2.422211398301462
# On day 1999-07-05
# Heldout Stouffer's Z (n=32763) 2.4133827119472935
# On day 1999-07-06
# Heldout Stouffer's Z (n=33013) 2.5167053892298914
# On day 1999-07-07
# Heldout Stouffer's Z (n=33236) 2.2970364900954636
# On day 1999-07-08
# Heldout Stouffer's Z (n=33453) 2.2628564969390106
# On day 1999-07-09
# Heldout Stouffer's Z (n=33686) 2.4027999153725457
# On day 1999-07-10
# Heldout Stouffer's Z (n=33906) 2.425164057768842
# On day 1999-07-11
# Heldout Stouffer's Z (n=34128) 2.4935670816358884
# On day 1999-07-12
# Heldout Stouffer's Z (n=34363) 2.3374958589331216
# On day 1999-07-13
# Heldout Stouffer's Z (n=34603) 2.4143350818622746
# On day 1999-07-14
# Heldout Stouffer's Z (n=34826) 2.435151557871629
# On day 1999-07-15
# Heldout Stouffer's Z (n=35063) 2.4940470890337703
# On day 1999-07-16
# Heldout Stouffer's Z (n=35282) 2.4739966382551883
# On day 1999-07-17
# Heldout Stouffer's Z (n=35517) 2.369474216138194
# On day 1999-07-18
# Heldout Stouffer's Z (n=35742) 2.3547552285999065
# On day 1999-07-19
# Heldout Stouffer's Z (n=35951) 2.3516979859882112
# On day 1999-07-20
# Heldout Stouffer's Z (n=36180) 2.348026245587281
# On day 1999-07-21
# Heldout Stouffer's Z (n=36403) 2.268559310904913
# On day 1999-07-22
# Heldout Stouffer's Z (n=36623) 2.232149824862762
# On day 1999-07-23
# Heldout Stouffer's Z (n=36853) 2.1920883221781398
# On day 1999-07-24
# Heldout Stouffer's Z (n=37069) 2.090649273741833
# On day 1999-07-25
# Heldout Stouffer's Z (n=37286) 2.0437445039739788
# On day 1999-07-26
# Heldout Stouffer's Z (n=37498) 2.247919401312089
# On day 1999-07-27
# Heldout Stouffer's Z (n=37730) 2.227052137739971
# On day 1999-07-28
# Heldout Stouffer's Z (n=37939) 2.1942712884305555
# On day 1999-07-29
# Heldout Stouffer's Z (n=38179) 2.2034570728889995
# On day 1999-07-30
# Heldout Stouffer's Z (n=38415) 2.2548109904727127
# On day 1999-07-31
# Heldout Stouffer's Z (n=38650) 2.3028842595799186
# On day 1999-08-01
# Heldout Stouffer's Z (n=38907) 2.2443057804741153
# On day 1999-08-02
# Heldout Stouffer's Z (n=39147) 2.2795941276991294
# On day 1999-08-03
# Heldout Stouffer's Z (n=39338) 2.2579960871776033
# On day 1999-08-04
# Heldout Stouffer's Z (n=39560) 2.0771126700680034
# On day 1999-08-05
# Heldout Stouffer's Z (n=39784) 2.0964076186617713
# On day 1999-08-06
# Heldout Stouffer's Z (n=39979) 2.222128884535121
# On day 1999-08-07
# Heldout Stouffer's Z (n=40225) 2.221365609644532
# On day 1999-08-08
# Heldout Stouffer's Z (n=40470) 2.2222699845899943
# On day 1999-08-09
# Heldout Stouffer's Z (n=40691) 2.223981191112969
# On day 1999-08-10
# Heldout Stouffer's Z (n=40891) 2.2275741628238226
# On day 1999-08-11
# Heldout Stouffer's Z (n=41113) 2.195795758501914
# On day 1999-08-12
# Heldout Stouffer's Z (n=41313) 2.0728793710748437
# On day 1999-08-13
# Heldout Stouffer's Z (n=41540) 2.130001145461889
# On day 1999-08-14
# Heldout Stouffer's Z (n=41767) 2.16893870117838
# On day 1999-08-15
# Heldout Stouffer's Z (n=41984) 1.976351051453768
# On day 1999-08-16
# Heldout Stouffer's Z (n=42225) 1.8665590270993861
# On day 1999-08-17
# Heldout Stouffer's Z (n=42476) 2.00683944652544
# On day 1999-08-18
# Heldout Stouffer's Z (n=42690) 2.033710761313291
# On day 1999-08-19
# Heldout Stouffer's Z (n=42907) 2.007464169249203
# On day 1999-08-20
# Heldout Stouffer's Z (n=43140) 2.0442401233611025
# On day 1999-08-21
# Heldout Stouffer's Z (n=43378) 2.0193233451137464
# On day 1999-08-22
# Heldout Stouffer's Z (n=43594) 1.8559104528815076
# On day 1999-08-23
# Heldout Stouffer's Z (n=43804) 1.9086289098469909
# On day 1999-08-24
# Heldout Stouffer's Z (n=44023) 1.8405740062287443
# On day 1999-08-25
# Heldout Stouffer's Z (n=44238) 1.8899952530996245
# On day 1999-08-26
# Heldout Stouffer's Z (n=44497) 1.9089544985606912
# On day 1999-08-27
# Heldout Stouffer's Z (n=44740) 1.7873072190516552
# On day 1999-08-28
# Heldout Stouffer's Z (n=44963) 1.7652120947754804
# On day 1999-08-29
# Heldout Stouffer's Z (n=45169) 1.7382085276458095
# On day 1999-08-30
# Heldout Stouffer's Z (n=45394) 1.7371495194839888
# On day 1999-08-31
# Heldout Stouffer's Z (n=45611) 1.6270338069273034
# On day 1999-09-01
# Heldout Stouffer's Z (n=45856) 1.5829924195592244
# On day 1999-09-02
# Heldout Stouffer's Z (n=46087) 1.4888309381927107
# On day 1999-09-03
# Heldout Stouffer's Z (n=46333) 1.5142731664069409
# On day 1999-09-04
# Heldout Stouffer's Z (n=46568) 1.5701181952204597
# On day 1999-09-05
# Heldout Stouffer's Z (n=46799) 1.4701227162225872
# On day 1999-09-06
# Heldout Stouffer's Z (n=47038) 1.4306343756331181
# On day 1999-09-07
# Heldout Stouffer's Z (n=47284) 1.3514436518871638
# On day 1999-09-08
# Heldout Stouffer's Z (n=47515) 1.3691076503108843
# On day 1999-09-09
# Heldout Stouffer's Z (n=47739) 1.350668047507487
# On day 1999-09-10
# Heldout Stouffer's Z (n=47967) 1.398158884029772
# On day 1999-09-11
# Heldout Stouffer's Z (n=48213) 1.3486860112677381
# On day 1999-09-12
# Heldout Stouffer's Z (n=48437) 1.3782509792609114
# On day 1999-09-13
# Heldout Stouffer's Z (n=48679) 1.5044527379783035
# On day 1999-09-14
# Heldout Stouffer's Z (n=48911) 1.45863575830474
# On day 1999-09-15
# Heldout Stouffer's Z (n=49132) 1.505604218681627
# On day 1999-09-16
# Heldout Stouffer's Z (n=49368) 1.388231312875707
# On day 1999-09-17
# Heldout Stouffer's Z (n=49597) 1.5389000404985984
# On day 1999-09-18
# Heldout Stouffer's Z (n=49819) 1.5336182928086848
# On day 1999-09-19
# Heldout Stouffer's Z (n=50025) 1.5058700302155097
# On day 1999-09-20
# Heldout Stouffer's Z (n=50261) 1.565555384013097
# On day 1999-09-21
# Heldout Stouffer's Z (n=50475) 1.5967868845809972
# On day 1999-09-22
# Heldout Stouffer's Z (n=50699) 1.597182171752937
# On day 1999-09-23
# Heldout Stouffer's Z (n=50929) 1.4958581067153134
# On day 1999-09-24
# Heldout Stouffer's Z (n=51164) 1.4777204498552823
# On day 1999-09-25
# Heldout Stouffer's Z (n=51352) 1.5565373914172422
# On day 1999-09-26
# Heldout Stouffer's Z (n=51585) 1.5454318089018646
# On day 1999-09-27
# Heldout Stouffer's Z (n=51822) 1.4357777071722149
# On day 1999-09-28
# Heldout Stouffer's Z (n=52064) 1.438959336953102
# On day 1999-09-29
# Heldout Stouffer's Z (n=52306) 1.4476961075105017
# On day 1999-09-30
# Heldout Stouffer's Z (n=52548) 1.401799236707309
# On day 1999-10-01
# Heldout Stouffer's Z (n=52780) 1.4004108205816401
# On day 1999-10-02
# Heldout Stouffer's Z (n=52989) 1.4175824871377876
# On day 1999-10-03
# Heldout Stouffer's Z (n=53241) 1.4569602602469796
# On day 1999-10-04
# Heldout Stouffer's Z (n=53470) 1.4481049535918298
# On day 1999-10-05
# Heldout Stouffer's Z (n=53687) 1.3923250200587218
# On day 1999-10-06
# Heldout Stouffer's Z (n=53913) 1.3042174558462214
# On day 1999-10-07
# Heldout Stouffer's Z (n=54173) 1.326705697767617
# On day 1999-10-08
# Heldout Stouffer's Z (n=54412) 1.3704344130029222
# On day 1999-10-09
# Heldout Stouffer's Z (n=54621) 1.3782362606212342
# On day 1999-10-10
# Heldout Stouffer's Z (n=54852) 1.3316491912255235
# On day 1999-10-11
# Heldout Stouffer's Z (n=55098) 1.3343082529236179
# On day 1999-10-12
# Heldout Stouffer's Z (n=55319) 1.247316849143614
# On day 1999-10-13
# Heldout Stouffer's Z (n=55543) 1.1938258586695154
# On day 1999-10-14
# Heldout Stouffer's Z (n=55750) 1.1381554680156876
# On day 1999-10-15
# Heldout Stouffer's Z (n=55996) 1.1289254353890605
# On day 1999-10-16
# Heldout Stouffer's Z (n=56221) 1.0765133114068441
# On day 1999-10-17
# Heldout Stouffer's Z (n=56464) 1.0499512275821552
# On day 1999-10-18
# Heldout Stouffer's Z (n=56695) 1.0303820225824631
# On day 1999-10-19
# Heldout Stouffer's Z (n=56899) 1.0642228981392383
# On day 1999-10-20
# Heldout Stouffer's Z (n=57101) 1.005479605280828
# On day 1999-10-21
# Heldout Stouffer's Z (n=57339) 1.0258076010250974
# On day 1999-10-22
# Heldout Stouffer's Z (n=57598) 1.0536347746455117
# On day 1999-10-23
# Heldout Stouffer's Z (n=57828) 1.1011221245142726
# On day 1999-10-24
# Heldout Stouffer's Z (n=58057) 1.088381064644654
# On day 1999-10-25
# Heldout Stouffer's Z (n=58289) 1.0074182404790093
# On day 1999-10-26
# Heldout Stouffer's Z (n=58528) 1.0148209039996785
# On day 1999-10-27
# Heldout Stouffer's Z (n=58770) 1.0204582785585352
# On day 1999-10-28
# Heldout Stouffer's Z (n=58981) 0.9776780670984639
# On day 1999-10-29
# Heldout Stouffer's Z (n=59185) 0.8910240979345794
# On day 1999-10-30
# Heldout Stouffer's Z (n=59410) 0.8311320792867143
# On day 1999-10-31
# Heldout Stouffer's Z (n=59606) 0.7472977626888125
# On day 1999-11-01
# Heldout Stouffer's Z (n=59836) 0.6902031293311953
# On day 1999-11-02
# Heldout Stouffer's Z (n=60088) 0.8320924009390099
# On day 1999-11-03
# Heldout Stouffer's Z (n=60320) 0.7930359584036921
# On day 1999-11-04
# Heldout Stouffer's Z (n=60548) 0.7645013935675632
# On day 1999-11-05
# Heldout Stouffer's Z (n=60785) 0.6825967716910705
# On day 1999-11-06
# Heldout Stouffer's Z (n=61008) 0.643059179108717
# On day 1999-11-07
# Heldout Stouffer's Z (n=61251) 0.6080096023007394
# On day 1999-11-08
# Heldout Stouffer's Z (n=61495) 0.509474197729899
# On day 1999-11-09
# Before masking, fraction of nans in raw data is 0.03877363040123457 for 1999-11-09 00:00:00 to 1999-11-09 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-09 00:00:00 to 1999-11-09 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.04214457947530864
# Heldout Stouffer's Z (n=61728) 0.5576117377881166
# On day 1999-11-10
# Before masking, fraction of nans in raw data is 0.07083285108024691 for 1999-11-10 00:00:00 to 1999-11-10 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-10 00:00:00 to 1999-11-10 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.07122347608024691
# Heldout Stouffer's Z (n=61960) 0.5857357589142258
# On day 1999-11-11
# Before masking, fraction of nans in raw data is 0.05045380015432099 for 1999-11-11 00:00:00 to 1999-11-11 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-11 00:00:00 to 1999-11-11 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.05087866512345679
# Heldout Stouffer's Z (n=62192) 0.5168376931763096
# On day 1999-11-12
# Before masking, fraction of nans in raw data is 0.11309751157407408 for 1999-11-12 00:00:00 to 1999-11-12 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-12 00:00:00 to 1999-11-12 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.11355324074074075
# Heldout Stouffer's Z (n=62411) 0.5748523789619063
# On day 1999-11-13
# Before masking, fraction of nans in raw data is 0.07630032206119162 for 1999-11-13 00:00:00 to 1999-11-13 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-13 00:00:00 to 1999-11-13 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.07683021336553945
# Heldout Stouffer's Z (n=62648) 0.5470526128417912
# On day 1999-11-14
# Before masking, fraction of nans in raw data is 0.08104015700483091 for 1999-11-14 00:00:00 to 1999-11-14 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-14 00:00:00 to 1999-11-14 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.08152475845410628
# Heldout Stouffer's Z (n=62881) 0.5818962937890563
# On day 1999-11-15
# Before masking, fraction of nans in raw data is 0.045034196127946124 for 1999-11-15 00:00:00 to 1999-11-15 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-15 00:00:00 to 1999-11-15 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.045618160774410776
# Heldout Stouffer's Z (n=63115) 0.535396605417977
# On day 1999-11-16
# Before masking, fraction of nans in raw data is 0.09450382447665057 for 1999-11-16 00:00:00 to 1999-11-16 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-16 00:00:00 to 1999-11-16 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.0951177536231884
# Heldout Stouffer's Z (n=63335) 0.5823805344225885
# On day 1999-11-17
# Before masking, fraction of nans in raw data is 0.11564284336419753 for 1999-11-17 00:00:00 to 1999-11-17 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-17 00:00:00 to 1999-11-17 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# Found 'rotten egg' entries for device id: 1026 in time range 1999-11-17 00:00:00 to 1999-11-17 23:59:59 (range: 1999-11-17 00:00:00 to 1999-12-30 23:59:59 )
# After masking, fraction of nans in raw data is 0.11754195601851852
# Heldout Stouffer's Z (n=63545) 0.6669486589580476
# On day 1999-11-18
# Before masking, fraction of nans in raw data is 0.10871527777777777 for 1999-11-18 00:00:00 to 1999-11-18 23:59:59
# Found 'rotten egg' entries for device id: 106 in time range 1999-11-18 00:00:00 to 1999-11-18 23:59:59 (range: 1999-11-18 00:00:00 to 1999-11-18 23:59:59 )
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-18 00:00:00 to 1999-11-18 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.10940720611916264
# Heldout Stouffer's Z (n=63761) 0.6775591677170656
# On day 1999-11-19
# Before masking, fraction of nans in raw data is 0.08327932098765432 for 1999-11-19 00:00:00 to 1999-11-19 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-19 00:00:00 to 1999-11-19 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.08401510141093474
# Heldout Stouffer's Z (n=64009) 0.6822564052308612
# On day 1999-11-20
# Before masking, fraction of nans in raw data is 0.09208701599326599 for 1999-11-20 00:00:00 to 1999-11-20 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-20 00:00:00 to 1999-11-20 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.09289825336700337
# Heldout Stouffer's Z (n=64232) 0.6786238687908072
# On day 1999-11-21
# Before masking, fraction of nans in raw data is 0.08834964225589226 for 1999-11-21 00:00:00 to 1999-11-21 23:59:59
# Found 'rotten egg' entries for device id: 1025 in time range 1999-11-21 00:00:00 to 1999-11-21 23:59:59 (range: 1999-11-09 00:00:00 to 1999-11-21 23:59:59 )
# After masking, fraction of nans in raw data is 0.08888099747474748
# Heldout Stouffer's Z (n=64458) 0.6369488587824913
# On day 1999-11-22
# Heldout Stouffer's Z (n=64693) 0.5524773171962968
# On day 1999-11-23
# Heldout Stouffer's Z (n=64936) 0.6026030856445957
# On day 1999-11-24
# Heldout Stouffer's Z (n=65155) 0.5818303785034946
# On day 1999-11-25
# Heldout Stouffer's Z (n=65370) 0.6754957909944661
# On day 1999-11-26
# Heldout Stouffer's Z (n=65616) 0.6094484295885673
# On day 1999-11-27
# Heldout Stouffer's Z (n=65831) 0.5997314273665196
# On day 1999-11-28
# Heldout Stouffer's Z (n=66064) 0.5912841031269573
# On day 1999-11-29
# Heldout Stouffer's Z (n=66305) 0.6885502895826913
# On day 1999-11-30
# Heldout Stouffer's Z (n=66524) 0.7505372960951764
# On day 1999-12-01
# Heldout Stouffer's Z (n=66763) 0.8379708449601827
# On day 1999-12-02
# Heldout Stouffer's Z (n=66985) 0.8941793774039578
# On day 1999-12-03
# Heldout Stouffer's Z (n=67233) 0.9035559802448359
# On day 1999-12-04
# Heldout Stouffer's Z (n=67466) 0.9149903931686836
# On day 1999-12-05
# Heldout Stouffer's Z (n=67709) 0.9195919793943174
# On day 1999-12-06
# Heldout Stouffer's Z (n=67916) 0.9465238403010748
# On day 1999-12-07
# Heldout Stouffer's Z (n=68127) 0.9377172409167813
# On day 1999-12-08
# Heldout Stouffer's Z (n=68364) 0.9040857897435941
# On day 1999-12-09
# Heldout Stouffer's Z (n=68594) 0.7888088209499655
# On day 1999-12-10
# Heldout Stouffer's Z (n=68829) 0.7365846430420658
# On day 1999-12-11
# Heldout Stouffer's Z (n=69040) 0.7425174616399686
# On day 1999-12-12
# Heldout Stouffer's Z (n=69259) 0.7673149061895324
# On day 1999-12-13
# Heldout Stouffer's Z (n=69483) 0.8756666595274036
# On day 1999-12-14
# Heldout Stouffer's Z (n=69693) 0.8143000228881453
# On day 1999-12-15
# Heldout Stouffer's Z (n=69919) 0.789200687157301
# On day 1999-12-16
# Heldout Stouffer's Z (n=70159) 0.7957167039628834
# On day 1999-12-17
# Heldout Stouffer's Z (n=70408) 0.7945702414338329
# On day 1999-12-18
# Heldout Stouffer's Z (n=70634) 0.7297287058833654
# On day 1999-12-19
# Heldout Stouffer's Z (n=70878) 0.7177412824116802
# On day 1999-12-20
# Heldout Stouffer's Z (n=71095) 0.8212306904379959
# On day 1999-12-21
# Heldout Stouffer's Z (n=71329) 0.8569003352048672
# On day 1999-12-22
# Heldout Stouffer's Z (n=71550) 0.9571941760197681
# On day 1999-12-23
# Heldout Stouffer's Z (n=71777) 0.9438253878572307
# On day 1999-12-24
# Heldout Stouffer's Z (n=72017) 1.0315763218004441
# On day 1999-12-25
# Heldout Stouffer's Z (n=72249) 0.9697703945799718
# On day 1999-12-26
# Heldout Stouffer's Z (n=72491) 1.0135120372777349
# On day 1999-12-27
# Heldout Stouffer's Z (n=72720) 1.0082200342771013
# On day 1999-12-28
# Heldout Stouffer's Z (n=72930) 0.9861611951457872
# On day 1999-12-29
# Heldout Stouffer's Z (n=73143) 1.0330822046989667
# On day 1999-12-30
# Before masking, fraction of nans in raw data is 0.013703275034293553 for 1999-12-30 00:00:00 to 1999-12-30 23:59:59
# Found 'rotten egg' entries for device id: 1026 in time range 1999-12-30 00:00:00 to 1999-12-30 23:59:59 (range: 1999-11-17 00:00:00 to 1999-12-30 23:59:59 )
# After masking, fraction of nans in raw data is 0.03783650548696845
# Heldout Stouffer's Z (n=73380) 1.0495285948433497
# On day 1999-12-31
# Heldout Stouffer's Z (n=73591) 1.0294566226891637
# On day 2000-01-01
# Heldout Stouffer's Z (n=73839) 1.0862712158601104
# On day 2000-01-02
# Heldout Stouffer's Z (n=74046) 1.1152217471981942
# On day 2000-01-03
# Heldout Stouffer's Z (n=74279) 1.070171966525267
# On day 2000-01-04
# Heldout Stouffer's Z (n=74506) 1.1264305331915996
# On day 2000-01-05
# Heldout Stouffer's Z (n=74733) 1.200270664285044
# On day 2000-01-06
# Heldout Stouffer's Z (n=74952) 1.1368680334361725
# On day 2000-01-07
# Heldout Stouffer's Z (n=75200) 1.0534097410940868
# On day 2000-01-08
# Heldout Stouffer's Z (n=75427) 1.0515501225985275
# On day 2000-01-09
# Heldout Stouffer's Z (n=75662) 1.0419440175179124
# On day 2000-01-10
# Heldout Stouffer's Z (n=75886) 1.0887013481210552
# On day 2000-01-11
# Heldout Stouffer's Z (n=76098) 1.007148596672631
# On day 2000-01-12
# Heldout Stouffer's Z (n=76320) 0.913190358419463
# On day 2000-01-13
# Heldout Stouffer's Z (n=76566) 0.9253901915452277
# On day 2000-01-14
# Heldout Stouffer's Z (n=76786) 0.9603862876079002
# On day 2000-01-15
# Heldout Stouffer's Z (n=76992) 1.0007213526155887
# On day 2000-01-16
# Heldout Stouffer's Z (n=77236) 1.0057697800869199
# On day 2000-01-17
# Heldout Stouffer's Z (n=77445) 1.0665616288501687
# On day 2000-01-18
# Heldout Stouffer's Z (n=77690) 1.1381588561968212
# On day 2000-01-19
# Heldout Stouffer's Z (n=77921) 1.1489326081423714
# On day 2000-01-20
# Heldout Stouffer's Z (n=78115) 1.1086704134765137
# On day 2000-01-21
# Heldout Stouffer's Z (n=78335) 1.120684125523466
# On day 2000-01-22
# Heldout Stouffer's Z (n=78591) 1.076446927655463
# On day 2000-01-23
# Heldout Stouffer's Z (n=78834) 0.9692761810685407
# On day 2000-01-24
# Heldout Stouffer's Z (n=79068) 0.9395927920743049
# On day 2000-01-25
# Heldout Stouffer's Z (n=79290) 1.0218503889728614
# On day 2000-01-26
# Heldout Stouffer's Z (n=79522) 0.8840124052694158
# On day 2000-01-27
# Heldout Stouffer's Z (n=79737) 0.8412810183574126
# On day 2000-01-28
# Heldout Stouffer's Z (n=79964) 0.9373764412179887
# On day 2000-01-29
# Heldout Stouffer's Z (n=80188) 0.9858032517890735
# On day 2000-01-30
# Heldout Stouffer's Z (n=80402) 0.9861190496347668
# On day 2000-01-31
# Heldout Stouffer's Z (n=80621) 0.9577610013344573
# On day 2000-02-01
# Heldout Stouffer's Z (n=80859) 0.9377847988841266
# On day 2000-02-02
# Heldout Stouffer's Z (n=81106) 0.8640053017269659
# On day 2000-02-03
# Heldout Stouffer's Z (n=81328) 0.7916632415510834
# On day 2000-02-04
# Heldout Stouffer's Z (n=81547) 0.8266831272628496
# On day 2000-02-05
# Heldout Stouffer's Z (n=81768) 0.9212775961302935
# On day 2000-02-06
# Heldout Stouffer's Z (n=82006) 0.9074494465554435
# On day 2000-02-07
# Heldout Stouffer's Z (n=82249) 0.8929977913582755
# On day 2000-02-08
# Heldout Stouffer's Z (n=82474) 0.9092610965701114
# On day 2000-02-09
# Heldout Stouffer's Z (n=82710) 0.9400047611587963
# On day 2000-02-10
# Heldout Stouffer's Z (n=82904) 1.0130566974193804
# On day 2000-02-11
# Heldout Stouffer's Z (n=83121) 0.9987769545595494
# On day 2000-02-12
# Heldout Stouffer's Z (n=83335) 1.026968046138663
# On day 2000-02-13
# Heldout Stouffer's Z (n=83552) 1.0481725962534365
# On day 2000-02-14
# Heldout Stouffer's Z (n=83787) 0.9923192332908374
# On day 2000-02-15
# Heldout Stouffer's Z (n=84017) 0.9696311388515345
# On day 2000-02-16
# Heldout Stouffer's Z (n=84249) 0.9555811955516925
# On day 2000-02-17
# Heldout Stouffer's Z (n=84470) 0.900588605234319
# On day 2000-02-18
# Heldout Stouffer's Z (n=84700) 0.9457815267389797
# On day 2000-02-19
# Heldout Stouffer's Z (n=84936) 1.0197001136852288
# On day 2000-02-20
# Heldout Stouffer's Z (n=85188) 1.072898616253288
# On day 2000-02-21
# Heldout Stouffer's Z (n=85427) 1.0720178428744431
# On day 2000-02-22
# Heldout Stouffer's Z (n=85647) 1.1018699831195498
# On day 2000-02-23
# Heldout Stouffer's Z (n=85863) 1.0825029234889467
# On day 2000-02-24
# Heldout Stouffer's Z (n=86101) 1.031190013928457
# On day 2000-02-25
# Heldout Stouffer's Z (n=86361) 0.9768154356699223
# On day 2000-02-26
# Heldout Stouffer's Z (n=86617) 1.0506712127377276
# On day 2000-02-27
# Heldout Stouffer's Z (n=86877) 1.0938680702369898
# On day 2000-02-28
# Heldout Stouffer's Z (n=87094) 1.0557841732537339
# On day 2000-02-29
# Heldout Stouffer's Z (n=87324) 1.0767300118379703
# On day 2000-03-01
# Heldout Stouffer's Z (n=87560) 1.0631056239013155
# On day 2000-03-02
# Heldout Stouffer's Z (n=87789) 1.1376106079478132
# On day 2000-03-03
# Heldout Stouffer's Z (n=88035) 1.038582778590022
# On day 2000-03-04
# Heldout Stouffer's Z (n=88273) 1.0408777095957882
# On day 2000-03-05
# Heldout Stouffer's Z (n=88522) 0.9858788232060635
# On day 2000-03-06
# Heldout Stouffer's Z (n=88755) 1.0183737969180628
# On day 2000-03-07
# Heldout Stouffer's Z (n=88972) 0.9751275201907296
# On day 2000-03-08
# Heldout Stouffer's Z (n=89200) 0.9301242567597472
# On day 2000-03-09
# Heldout Stouffer's Z (n=89420) 0.9291099039399854
# On day 2000-03-10
# Heldout Stouffer's Z (n=89638) 0.9088453732555363
# On day 2000-03-11
# Heldout Stouffer's Z (n=89867) 0.8831867124763448
# On day 2000-03-12
# Heldout Stouffer's Z (n=90096) 0.9357915681779932
# On day 2000-03-13
# Heldout Stouffer's Z (n=90338) 0.8912993605719428
# On day 2000-03-14
# Heldout Stouffer's Z (n=90574) 0.8908599519389562
# On day 2000-03-15
# Heldout Stouffer's Z (n=90795) 0.8552966332424917
# On day 2000-03-16
# Heldout Stouffer's Z (n=91016) 0.894837767994449
# On day 2000-03-17
# Heldout Stouffer's Z (n=91223) 0.9432493673116845
# On day 2000-03-18
# Heldout Stouffer's Z (n=91456) 0.8587089108260202
# On day 2000-03-19
# Heldout Stouffer's Z (n=91678) 0.8974684352962286
# On day 2000-03-20
# Heldout Stouffer's Z (n=91906) 0.8494033567593838
# On day 2000-03-21
# Heldout Stouffer's Z (n=92136) 0.8655145805141583
# On day 2000-03-22
# Heldout Stouffer's Z (n=92386) 0.9188305894303395
# On day 2000-03-23
# Heldout Stouffer's Z (n=92592) 0.8939205585318751
# On day 2000-03-24
# Heldout Stouffer's Z (n=92810) 0.8089741220929871
# On day 2000-03-25
# Heldout Stouffer's Z (n=93025) 0.8826274338481821
# On day 2000-03-26
# Heldout Stouffer's Z (n=93251) 0.8926994782172495
# On day 2000-03-27
# Heldout Stouffer's Z (n=93496) 0.8964262181095279
# On day 2000-03-28
# Heldout Stouffer's Z (n=93743) 0.9266519806000239
# On day 2000-03-29
# Heldout Stouffer's Z (n=93984) 0.8500973295645563
# On day 2000-03-30
# Heldout Stouffer's Z (n=94218) 0.8481852014796163
# On day 2000-03-31
# Heldout Stouffer's Z (n=94441) 0.8625240401479023
# On day 2000-04-01
# Heldout Stouffer's Z (n=94676) 0.8806530380967383
# On day 2000-04-02
# Heldout Stouffer's Z (n=94893) 0.9171072033376938
# On day 2000-04-03
# Heldout Stouffer's Z (n=95155) 0.9048287773136344
# On day 2000-04-04
# Heldout Stouffer's Z (n=95397) 0.8635941789211603
# On day 2000-04-05
# Heldout Stouffer's Z (n=95613) 0.8733188053712315
# On day 2000-04-06
# Heldout Stouffer's Z (n=95857) 0.8965216321820572
# On day 2000-04-07
# Heldout Stouffer's Z (n=96084) 0.928874964745802
# On day 2000-04-08
# Heldout Stouffer's Z (n=96305) 0.8519555670379478
# On day 2000-04-09
# Heldout Stouffer's Z (n=96531) 0.8231334346034352
# On day 2000-04-10
# Heldout Stouffer's Z (n=96769) 0.8149932892227234
# On day 2000-04-11
# Heldout Stouffer's Z (n=96963) 0.7654577260506322
# On day 2000-04-12
# Heldout Stouffer's Z (n=97203) 0.7187199091357852
# On day 2000-04-13
# Heldout Stouffer's Z (n=97419) 0.8129591176852813
# On day 2000-04-14
# Heldout Stouffer's Z (n=97662) 0.7983848997454174
# On day 2000-04-15
# Heldout Stouffer's Z (n=97890) 0.7038402373015892
# On day 2000-04-16
# Heldout Stouffer's Z (n=98127) 0.7104483882181698
# On day 2000-04-17
# Heldout Stouffer's Z (n=98352) 0.7410278443202969
# On day 2000-04-18
# Heldout Stouffer's Z (n=98572) 0.6783842641443205
# On day 2000-04-19
# Heldout Stouffer's Z (n=98805) 0.6321293466994021
# On day 2000-04-20
# Heldout Stouffer's Z (n=99032) 0.6668780989715551
# On day 2000-04-21
# Heldout Stouffer's Z (n=99266) 0.689205254947238
# On day 2000-04-22
# Heldout Stouffer's Z (n=99498) 0.7909031851785429
# On day 2000-04-23
# Heldout Stouffer's Z (n=99716) 0.7746949226961414
# On day 2000-04-24
# Heldout Stouffer's Z (n=99946) 0.7883017012155416
# On day 2000-04-25
# Heldout Stouffer's Z (n=100160) 0.7495576205314497
# On day 2000-04-26
# Heldout Stouffer's Z (n=100377) 0.7247536273655854
# On day 2000-04-27
# Heldout Stouffer's Z (n=100609) 0.7179624532292493
# On day 2000-04-28
# Heldout Stouffer's Z (n=100860) 0.715075981437403
# On day 2000-04-29
# Heldout Stouffer's Z (n=101108) 0.7286329275147431
# On day 2000-04-30
# Heldout Stouffer's Z (n=101325) 0.691643586383618
# On day 2000-05-01
# Heldout Stouffer's Z (n=101537) 0.6174211559141002
# On day 2000-05-02
# Heldout Stouffer's Z (n=101765) 0.657083594835518
# On day 2000-05-03
# Heldout Stouffer's Z (n=101975) 0.6419432144375194
# On day 2000-05-04
# Heldout Stouffer's Z (n=102179) 0.6065403236519064
# On day 2000-05-05
# Heldout Stouffer's Z (n=102407) 0.5910795470745703
# On day 2000-05-06
# Heldout Stouffer's Z (n=102631) 0.6252342923559666
# On day 2000-05-07
# Heldout Stouffer's Z (n=102873) 0.6066186751546082
# On day 2000-05-08
# Heldout Stouffer's Z (n=103116) 0.6003842006351654
# On day 2000-05-09
# Heldout Stouffer's Z (n=103347) 0.5853159484929069
# On day 2000-05-10
# Heldout Stouffer's Z (n=103560) 0.5746376104574716
# On day 2000-05-11
# Heldout Stouffer's Z (n=103777) 0.6108737450910937
# On day 2000-05-12
# Heldout Stouffer's Z (n=103988) 0.6274448295010565
# On day 2000-05-13
# Heldout Stouffer's Z (n=104239) 0.658412941820956
# On day 2000-05-14
# Heldout Stouffer's Z (n=104487) 0.6547408126105604
# On day 2000-05-15
# Heldout Stouffer's Z (n=104708) 0.6451243059162285
# On day 2000-05-16
# Heldout Stouffer's Z (n=104946) 0.6568074316846367
# On day 2000-05-17
# Heldout Stouffer's Z (n=105179) 0.711095068332571
# On day 2000-05-18
# Heldout Stouffer's Z (n=105408) 0.6634327053063959
# On day 2000-05-19
# Heldout Stouffer's Z (n=105627) 0.7225212526034656
# On day 2000-05-20
# Heldout Stouffer's Z (n=105849) 0.7729465159292457
# On day 2000-05-21
# Heldout Stouffer's Z (n=106060) 0.7433691044360365
# On day 2000-05-22
# Heldout Stouffer's Z (n=106312) 0.6656079073074295
# On day 2000-05-23
# Heldout Stouffer's Z (n=106563) 0.6731229464032055
# On day 2000-05-24
# Heldout Stouffer's Z (n=106781) 0.7542719743171163
# On day 2000-05-25
# Heldout Stouffer's Z (n=106982) 0.7861202397221669
# On day 2000-05-26
# Heldout Stouffer's Z (n=107200) 0.7692331873369329
# On day 2000-05-27
# Heldout Stouffer's Z (n=107419) 0.7628721576403686
# On day 2000-05-28
# Heldout Stouffer's Z (n=107672) 0.7750805308860822
# On day 2000-05-29
# Heldout Stouffer's Z (n=107895) 0.8348823221309845
# On day 2000-05-30
# Heldout Stouffer's Z (n=108125) 0.8033946551187219
# On day 2000-05-31
# Heldout Stouffer's Z (n=108361) 0.7798208088851766
# On day 2000-06-01
# Heldout Stouffer's Z (n=108584) 0.81740081668749
# On day 2000-06-02
# Heldout Stouffer's Z (n=108797) 0.8280117063898763
# On day 2000-06-03
# Heldout Stouffer's Z (n=109041) 0.8483067714048319
# On day 2000-06-04
# Heldout Stouffer's Z (n=109260) 0.9266332190230488
# On day 2000-06-05
# Heldout Stouffer's Z (n=109497) 0.8877416580470271
# On day 2000-06-06
# Heldout Stouffer's Z (n=109733) 0.8856232025818147
# On day 2000-06-07
# Heldout Stouffer's Z (n=109954) 0.8564581950395928
# On day 2000-06-08
# Heldout Stouffer's Z (n=110184) 0.7961016235752075
# On day 2000-06-09
# Heldout Stouffer's Z (n=110432) 0.8206335433082619
# On day 2000-06-10
# Heldout Stouffer's Z (n=110665) 0.8552943379125262
# On day 2000-06-11
# Heldout Stouffer's Z (n=110882) 0.8257084508516351
# On day 2000-06-12
# Heldout Stouffer's Z (n=111134) 0.8465036282665741
# On day 2000-06-13
# Heldout Stouffer's Z (n=111356) 0.8121997145884082
# On day 2000-06-14
# Heldout Stouffer's Z (n=111580) 0.8896493380231484
# On day 2000-06-15
# Heldout Stouffer's Z (n=111808) 0.8939690826755843
# On day 2000-06-16
# Heldout Stouffer's Z (n=112016) 0.9011842271630834
# On day 2000-06-17
# Heldout Stouffer's Z (n=112223) 0.906365557647644
# On day 2000-06-18
# Heldout Stouffer's Z (n=112451) 0.9328032399806213
# On day 2000-06-19
# Heldout Stouffer's Z (n=112699) 0.9373407502819615
# On day 2000-06-20
# Heldout Stouffer's Z (n=112935) 0.8486039674154277
# On day 2000-06-21
# Heldout Stouffer's Z (n=113172) 0.8219446934008896
# On day 2000-06-22
# Heldout Stouffer's Z (n=113367) 0.8313068714431984
# On day 2000-06-23
# Heldout Stouffer's Z (n=113583) 0.762089854978667
# On day 2000-06-24
# Heldout Stouffer's Z (n=113833) 0.7556998872585217
# On day 2000-06-25
# Heldout Stouffer's Z (n=114065) 0.7107663590750506
# On day 2000-06-26
# Heldout Stouffer's Z (n=114300) 0.7062665851334771
# On day 2000-06-27
# Heldout Stouffer's Z (n=114523) 0.6551664806732603
# On day 2000-06-28
# Heldout Stouffer's Z (n=114738) 0.6647686300409621
# On day 2000-06-29
# Heldout Stouffer's Z (n=114975) 0.6039458323044693
# On day 2000-06-30
# Heldout Stouffer's Z (n=115222) 0.5810378225107932
# On day 2000-07-01
# Heldout Stouffer's Z (n=115425) 0.7017539025085429
# On day 2000-07-02
# Heldout Stouffer's Z (n=115661) 0.703668304532628
# On day 2000-07-03
# Heldout Stouffer's Z (n=115896) 0.6830698062357161
# On day 2000-07-04
# Heldout Stouffer's Z (n=116117) 0.7268054200839721
# On day 2000-07-05
# Heldout Stouffer's Z (n=116362) 0.7426218139216545
# ...
# On day 2016-04-08
# Heldout Stouffer's Z (n=1426499) 0.8017770778227642
# On day 2016-04-09
# Heldout Stouffer's Z (n=1426754) 0.8169154847175047
# On day 2016-04-10
# Heldout Stouffer's Z (n=1426976) 0.8030134442465113
# On day 2016-04-11
# Heldout Stouffer's Z (n=1427216) 0.7941674922370883
# On day 2016-04-12
# Heldout Stouffer's Z (n=1427445) 0.7693951675724984
# On day 2016-04-13
# Heldout Stouffer's Z (n=1427670) 0.7775826944023879
# On day 2016-04-14
# Heldout Stouffer's Z (n=1427903) 0.7817963659178693
# On day 2016-04-15
# Heldout Stouffer's Z (n=1428159) 0.796975874936256
# On day 2016-04-16
# Heldout Stouffer's Z (n=1428370) 0.7931863294722726
# On day 2016-04-17
# Heldout Stouffer's Z (n=1428617) 0.7695409748968988
# On day 2016-04-18
# Heldout Stouffer's Z (n=1428843) 0.7702297367330427
# On day 2016-04-19
# Heldout Stouffer's Z (n=1429077) 0.785500694118493
# On day 2016-04-20
# Heldout Stouffer's Z (n=1429332) 0.7867522502992603
# On day 2016-04-21
# Heldout Stouffer's Z (n=1429537) 0.7826389474525971
# On day 2016-04-22
# Heldout Stouffer's Z (n=1429754) 0.7796206297305094
# On day 2016-04-23
# Heldout Stouffer's Z (n=1429972) 0.7896407543930722
# On day 2016-04-24
# Heldout Stouffer's Z (n=1430226) 0.8016380853628835
# On day 2016-04-25
# Heldout Stouffer's Z (n=1430463) 0.7998521139011459
# On day 2016-04-26
# Heldout Stouffer's Z (n=1430672) 0.8283306248160743
# On day 2016-04-27
# Heldout Stouffer's Z (n=1430910) 0.8351926514991518
# On day 2016-04-28
# Heldout Stouffer's Z (n=1431129) 0.8261461973435809
# On day 2016-04-29
# Heldout Stouffer's Z (n=1431371) 0.8311280097156314
# On day 2016-04-30
# Heldout Stouffer's Z (n=1431599) 0.8220087527315029
# On day 2016-05-01
# Heldout Stouffer's Z (n=1431844) 0.8205490598582981
# On day 2016-05-02
# Heldout Stouffer's Z (n=1432055) 0.8200295635529248
# On day 2016-05-03
# Heldout Stouffer's Z (n=1432300) 0.8298215131355915
# On day 2016-05-04
# Heldout Stouffer's Z (n=1432524) 0.8339962717758646
# On day 2016-05-05
# Heldout Stouffer's Z (n=1432776) 0.829882594276862
# On day 2016-05-06
# Heldout Stouffer's Z (n=1433007) 0.8109211024241859
# On day 2016-05-07
# Heldout Stouffer's Z (n=1433241) 0.8186203359373319
# On day 2016-05-08
# Heldout Stouffer's Z (n=1433467) 0.7960524745052482
# On day 2016-05-09
# Heldout Stouffer's Z (n=1433708) 0.818599981366862
# On day 2016-05-10
# Heldout Stouffer's Z (n=1433949) 0.8142005653457912
# On day 2016-05-11
# Heldout Stouffer's Z (n=1434193) 0.8136983864168033
# On day 2016-05-12
# Heldout Stouffer's Z (n=1434402) 0.7984986582590423
# On day 2016-05-13
# Heldout Stouffer's Z (n=1434635) 0.8184338941425138
# On day 2016-05-14
# Heldout Stouffer's Z (n=1434871) 0.8416225069581652
# On day 2016-05-15
# Heldout Stouffer's Z (n=1435108) 0.8445219254785787
# On day 2016-05-16
# Heldout Stouffer's Z (n=1435323) 0.8585000813159922
# On day 2016-05-17
# Heldout Stouffer's Z (n=1435543) 0.8431179503274557
# On day 2016-05-18
# Heldout Stouffer's Z (n=1435777) 0.8440692829946917
# On day 2016-05-19
# Heldout Stouffer's Z (n=1436029) 0.82902568858768
# On day 2016-05-20
# Heldout Stouffer's Z (n=1436258) 0.824148297052424
# On day 2016-05-21
# Heldout Stouffer's Z (n=1436497) 0.822812764113343
# On day 2016-05-22
# Heldout Stouffer's Z (n=1436716) 0.8309347866100767
# On day 2016-05-23
# Heldout Stouffer's Z (n=1436937) 0.8127837197957559
# On day 2016-05-24
# Heldout Stouffer's Z (n=1437153) 0.7968677622660999
# On day 2016-05-25
# Heldout Stouffer's Z (n=1437368) 0.7814384521470569
# On day 2016-05-26
# Heldout Stouffer's Z (n=1437583) 0.7802999180360086
# On day 2016-05-27
# Heldout Stouffer's Z (n=1437789) 0.7791040705473912
# On day 2016-05-28
# Heldout Stouffer's Z (n=1437998) 0.7835337447638903
# On day 2016-05-29
# Heldout Stouffer's Z (n=1438208) 0.7729358000874033
# On day 2016-05-30
# Heldout Stouffer's Z (n=1438437) 0.7938930845468133
# On day 2016-05-31
# Heldout Stouffer's Z (n=1438680) 0.8014836690150388
# On day 2016-06-01
# Heldout Stouffer's Z (n=1438899) 0.7914766610327407
# On day 2016-06-02
# Heldout Stouffer's Z (n=1439142) 0.7790374771102401
# On day 2016-06-03
# Heldout Stouffer's Z (n=1439384) 0.7816753290247318
# On day 2016-06-04
# Heldout Stouffer's Z (n=1439582) 0.7773228189580808
# On day 2016-06-05
# Heldout Stouffer's Z (n=1439798) 0.785867577954409
# On day 2016-06-06
# Heldout Stouffer's Z (n=1440017) 0.7858895987542989
# On day 2016-06-07
# Heldout Stouffer's Z (n=1440247) 0.7715568156167861
# On day 2016-06-08
# Heldout Stouffer's Z (n=1440460) 0.7886838352194506
# On day 2016-06-09
# Heldout Stouffer's Z (n=1440658) 0.8002813545266089
# On day 2016-06-10
# Heldout Stouffer's Z (n=1440892) 0.7953261671985927
# On day 2016-06-11
# Heldout Stouffer's Z (n=1441150) 0.8172251654405691
# On day 2016-06-12
# Heldout Stouffer's Z (n=1441372) 0.8249810079368066
# On day 2016-06-13
# Heldout Stouffer's Z (n=1441581) 0.8179647357620726
# On day 2016-06-14
# Heldout Stouffer's Z (n=1441833) 0.8170501825922376
# On day 2016-06-15
# Heldout Stouffer's Z (n=1442081) 0.8121405989071367
# On day 2016-06-16
# Heldout Stouffer's Z (n=1442294) 0.826932010883696
# On day 2016-06-17
# Heldout Stouffer's Z (n=1442519) 0.8296335907139404
# On day 2016-06-18
# Heldout Stouffer's Z (n=1442730) 0.8189888354418626
# On day 2016-06-19
# Heldout Stouffer's Z (n=1442933) 0.8250198991721388
# On day 2016-06-20
# Heldout Stouffer's Z (n=1443150) 0.8483339160728951
# On day 2016-06-21
# Heldout Stouffer's Z (n=1443383) 0.8436108491782821
# On day 2016-06-22
# Heldout Stouffer's Z (n=1443597) 0.8517195213108193
# On day 2016-06-23
# Heldout Stouffer's Z (n=1443804) 0.8344074952017693
# On day 2016-06-24
# Heldout Stouffer's Z (n=1444036) 0.8549631994801027
# On day 2016-06-25
# Heldout Stouffer's Z (n=1444250) 0.8346701853886584
# On day 2016-06-26
# Heldout Stouffer's Z (n=1444472) 0.8320608453850793
# On day 2016-06-27
# Heldout Stouffer's Z (n=1444715) 0.8337493728758415
# On day 2016-06-28
# Heldout Stouffer's Z (n=1444916) 0.8593969488179332
# On day 2016-06-29
# Heldout Stouffer's Z (n=1445162) 0.8617807319139544
# On day 2016-06-30
# Heldout Stouffer's Z (n=1445383) 0.8620601739290379
# On day 2016-07-01
# Heldout Stouffer's Z (n=1445607) 0.8775390941620628
# On day 2016-07-02
# Heldout Stouffer's Z (n=1445833) 0.8846403823918451
# On day 2016-07-03
# Heldout Stouffer's Z (n=1446070) 0.8963595422025575
# On day 2016-07-04
# Heldout Stouffer's Z (n=1446295) 0.918232416306234
# On day 2016-07-05
# Heldout Stouffer's Z (n=1446522) 0.9082124673980925
# On day 2016-07-06
# Heldout Stouffer's Z (n=1446744) 0.9011759816292658
# On day 2016-07-07
# Heldout Stouffer's Z (n=1446963) 0.8833177389460455
# On day 2016-07-08
# Heldout Stouffer's Z (n=1447193) 0.8880458676481303
# On day 2016-07-09
# Heldout Stouffer's Z (n=1447413) 0.9015755068046781
# On day 2016-07-10
# Heldout Stouffer's Z (n=1447634) 0.9194445128282385
# On day 2016-07-11
# Heldout Stouffer's Z (n=1447873) 0.896016504816597
# On day 2016-07-12
# Heldout Stouffer's Z (n=1448080) 0.880969646629589
# On day 2016-07-13
# Heldout Stouffer's Z (n=1448300) 0.8823333900858645
# On day 2016-07-14
# Heldout Stouffer's Z (n=1448517) 0.8865932760195752
# On day 2016-07-15
# Heldout Stouffer's Z (n=1448734) 0.8952085393759659
# On day 2016-07-16
# Heldout Stouffer's Z (n=1448970) 0.8881699887600086
# On day 2016-07-17
# Heldout Stouffer's Z (n=1449192) 0.8796625782588628
# On day 2016-07-18
# Heldout Stouffer's Z (n=1449426) 0.869673433960705
# On day 2016-07-19
# Heldout Stouffer's Z (n=1449653) 0.8761725035361397
# On day 2016-07-20
# Heldout Stouffer's Z (n=1449907) 0.8640180396065301
# On day 2016-07-21
# Heldout Stouffer's Z (n=1450131) 0.8366171145823462
# On day 2016-07-22
# Heldout Stouffer's Z (n=1450345) 0.8557681291359163
# On day 2016-07-23
# Heldout Stouffer's Z (n=1450588) 0.8601850529976084
# On day 2016-07-24
# Heldout Stouffer's Z (n=1450823) 0.8721873316601407
# On day 2016-07-25
# Heldout Stouffer's Z (n=1451036) 0.8942427537887974
# On day 2016-07-26
# Heldout Stouffer's Z (n=1451257) 0.8959236559196276
# On day 2016-07-27
# Heldout Stouffer's Z (n=1451487) 0.8799715793096291
# On day 2016-07-28
# Heldout Stouffer's Z (n=1451721) 0.9016656821997237
# On day 2016-07-29
# Heldout Stouffer's Z (n=1451965) 0.8925693598500529
# On day 2016-07-30
# Heldout Stouffer's Z (n=1452191) 0.8751320624234433
# On day 2016-07-31
# Heldout Stouffer's Z (n=1452425) 0.8813837186120079
# On day 2016-08-01
# Heldout Stouffer's Z (n=1452649) 0.8745490813857731
# On day 2016-08-02
# Heldout Stouffer's Z (n=1452871) 0.8681580573284408
# On day 2016-08-03
# Heldout Stouffer's Z (n=1453106) 0.8397290173971744
# On day 2016-08-04
# Heldout Stouffer's Z (n=1453321) 0.833786708200848
# On day 2016-08-05
# Heldout Stouffer's Z (n=1453560) 0.7972418315059178
# On day 2016-08-06
# Heldout Stouffer's Z (n=1453788) 0.8177434982075329
# On day 2016-08-07
# Heldout Stouffer's Z (n=1454034) 0.7968766801161282
# On day 2016-08-08
# Heldout Stouffer's Z (n=1454236) 0.7939003620675336
# On day 2016-08-09
# Heldout Stouffer's Z (n=1454448) 0.8019147912759471
# On day 2016-08-10
# Heldout Stouffer's Z (n=1454666) 0.7904557971808601
# On day 2016-08-11
# Heldout Stouffer's Z (n=1454885) 0.7677362878851925
# On day 2016-08-12
# Heldout Stouffer's Z (n=1455110) 0.7691024433896283
# On day 2016-08-13
# Heldout Stouffer's Z (n=1455346) 0.7759714495822239
# On day 2016-08-14
# Heldout Stouffer's Z (n=1455581) 0.7659039296494007
# On day 2016-08-15
# Heldout Stouffer's Z (n=1455795) 0.7692250007739572
# On day 2016-08-16
# Heldout Stouffer's Z (n=1456045) 0.7788865588978318
# On day 2016-08-17
# Heldout Stouffer's Z (n=1456253) 0.7777675692588417
# On day 2016-08-18
# Heldout Stouffer's Z (n=1456453) 0.7814045103696506
# On day 2016-08-19
# Heldout Stouffer's Z (n=1456668) 0.769441970442965
# On day 2016-08-20
# Heldout Stouffer's Z (n=1456901) 0.7663327641784226
# On day 2016-08-21
# Heldout Stouffer's Z (n=1457114) 0.7634744758893719
# On day 2016-08-22
# Heldout Stouffer's Z (n=1457359) 0.7596401394702483
# On day 2016-08-23
# Heldout Stouffer's Z (n=1457589) 0.7580991933455108
# On day 2016-08-24
# Heldout Stouffer's Z (n=1457798) 0.7742991923328495
# On day 2016-08-25
# Heldout Stouffer's Z (n=1458036) 0.7664092579065139
# On day 2016-08-26
# Heldout Stouffer's Z (n=1458265) 0.755250926926152
# On day 2016-08-27
# Heldout Stouffer's Z (n=1458476) 0.7643837340810846
# On day 2016-08-28
# Heldout Stouffer's Z (n=1458697) 0.7732363718112696
# On day 2016-08-29
# Heldout Stouffer's Z (n=1458950) 0.7693550783561726
# On day 2016-08-30
# Heldout Stouffer's Z (n=1459193) 0.7788393970005726
# On day 2016-08-31
# MISSING DATA ERROR! query for day 2016-08-31 ends at 1472687999.0 but data for day ends at 1472651399
# Heldout Stouffer's Z (n=1459193) 0.7788393970005726
# On day 2016-09-01
# Heldout Stouffer's Z (n=1459408) 0.8027519069471426
# On day 2016-09-02
# Heldout Stouffer's Z (n=1459632) 0.7927760778605075
# On day 2016-09-03
# Heldout Stouffer's Z (n=1459884) 0.7965347718276862
# On day 2016-09-04
# Heldout Stouffer's Z (n=1460107) 0.773575937614119
# On day 2016-09-05
# Heldout Stouffer's Z (n=1460334) 0.7626437108736916
# On day 2016-09-06
# Heldout Stouffer's Z (n=1460585) 0.7639865282881699
# On day 2016-09-07
# Heldout Stouffer's Z (n=1460790) 0.7452077479475839
# On day 2016-09-08
# Heldout Stouffer's Z (n=1461030) 0.7570219747230466
# On day 2016-09-09
# Heldout Stouffer's Z (n=1461250) 0.7778510090274718
# On day 2016-09-10
# Heldout Stouffer's Z (n=1461464) 0.7827739423379861
# On day 2016-09-11
# Heldout Stouffer's Z (n=1461715) 0.7847205763556145
# On day 2016-09-12
# Heldout Stouffer's Z (n=1461935) 0.7929456313400106
# On day 2016-09-13
# MISSING DATA ERROR! query for day 2016-09-13 ends at 1473811199.0 but data for day ends at 1473724799
# Heldout Stouffer's Z (n=1461935) 0.7929456313400106
# On day 2016-09-14
# Heldout Stouffer's Z (n=1462162) 0.7884353658926239
# On day 2016-09-15
# Heldout Stouffer's Z (n=1462388) 0.7970275431273308
# On day 2016-09-16
# Heldout Stouffer's Z (n=1462608) 0.7936834787725972
# On day 2016-09-17
# Heldout Stouffer's Z (n=1462816) 0.8056333002941003
# On day 2016-09-18
# Heldout Stouffer's Z (n=1463053) 0.7915934219843812
# On day 2016-09-19
# Heldout Stouffer's Z (n=1463287) 0.7939503369009868
# On day 2016-09-20
# Heldout Stouffer's Z (n=1463529) 0.8015058986773125
# On day 2016-09-21
# Heldout Stouffer's Z (n=1463741) 0.8059814489306473
# On day 2016-09-22
# Heldout Stouffer's Z (n=1463967) 0.821910592627032
# On day 2016-09-23
# Heldout Stouffer's Z (n=1464224) 0.8318203429005722
# On day 2016-09-24
# Heldout Stouffer's Z (n=1464470) 0.8375012962379484
# On day 2016-09-25
# Heldout Stouffer's Z (n=1464711) 0.8377011734677002
# On day 2016-09-26
# Heldout Stouffer's Z (n=1464927) 0.8399782591530935
# On day 2016-09-27
# Heldout Stouffer's Z (n=1465148) 0.8413376433352053
# On day 2016-09-28
# Heldout Stouffer's Z (n=1465365) 0.8556269573622574
# On day 2016-09-29
# Heldout Stouffer's Z (n=1465580) 0.8541850849929189
# On day 2016-09-30
# Heldout Stouffer's Z (n=1465782) 0.8613546741109491
# On day 2016-10-01
# Heldout Stouffer's Z (n=1466023) 0.8948160539692864
# On day 2016-10-02
# Heldout Stouffer's Z (n=1466253) 0.8935410902357326
# On day 2016-10-03
# Heldout Stouffer's Z (n=1466456) 0.8821384240293044
# On day 2016-10-04
# Heldout Stouffer's Z (n=1466691) 0.874802285685674
# On day 2016-10-05
# Heldout Stouffer's Z (n=1466932) 0.8619221606209285
# On day 2016-10-06
# Heldout Stouffer's Z (n=1467149) 0.8533228756496741
# On day 2016-10-07
# Heldout Stouffer's Z (n=1467377) 0.8429983292805813
# On day 2016-10-08
# Heldout Stouffer's Z (n=1467620) 0.8355752204309692
# On day 2016-10-09
# Heldout Stouffer's Z (n=1467860) 0.8394830671427996
# On day 2016-10-10
# Heldout Stouffer's Z (n=1468113) 0.8304957133785377
# On day 2016-10-11
# Heldout Stouffer's Z (n=1468336) 0.8206541141886821
# On day 2016-10-12
# Heldout Stouffer's Z (n=1468545) 0.8176297187637125
# On day 2016-10-13
# Heldout Stouffer's Z (n=1468766) 0.8070359029947841
# On day 2016-10-14
# Heldout Stouffer's Z (n=1468989) 0.7893842464022337
# On day 2016-10-15
# Heldout Stouffer's Z (n=1469195) 0.7579358603567764
# On day 2016-10-16
# Heldout Stouffer's Z (n=1469437) 0.7411543242424101
# On day 2016-10-17
# Heldout Stouffer's Z (n=1469669) 0.7384173347663722
# On day 2016-10-18
# Heldout Stouffer's Z (n=1469892) 0.7433495059827887
# On day 2016-10-19
# Heldout Stouffer's Z (n=1470116) 0.7264408351913695
# On day 2016-10-20
# Heldout Stouffer's Z (n=1470331) 0.7188910042537082
# On day 2016-10-21
# Heldout Stouffer's Z (n=1470558) 0.7220404022782293
# On day 2016-10-22
# Heldout Stouffer's Z (n=1470791) 0.7227273402863628
# On day 2016-10-23
# Heldout Stouffer's Z (n=1471002) 0.7178527981130606
# On day 2016-10-24
# Heldout Stouffer's Z (n=1471229) 0.7271545821857873
# On day 2016-10-25
# Heldout Stouffer's Z (n=1471464) 0.7236976005024659
# On day 2016-10-26
# Heldout Stouffer's Z (n=1471710) 0.6915333072338452
# On day 2016-10-27
# Heldout Stouffer's Z (n=1471962) 0.7208799858688505
# On day 2016-10-28
# Heldout Stouffer's Z (n=1472184) 0.689955169141111
# On day 2016-10-29
# Heldout Stouffer's Z (n=1472420) 0.6784408923181574
# On day 2016-10-30
# Heldout Stouffer's Z (n=1472668) 0.6703877445602736
# On day 2016-10-31
# Heldout Stouffer's Z (n=1472877) 0.676277965762125
# On day 2016-11-01
# Heldout Stouffer's Z (n=1473113) 0.6714406755613284
# On day 2016-11-02
# Heldout Stouffer's Z (n=1473345) 0.6914424009234846
# On day 2016-11-03
# Heldout Stouffer's Z (n=1473566) 0.7109921850637357
# On day 2016-11-04
# Heldout Stouffer's Z (n=1473786) 0.7283829582481965
# On day 2016-11-05
# Heldout Stouffer's Z (n=1473987) 0.7437616216711419
# On day 2016-11-06
# Heldout Stouffer's Z (n=1474221) 0.7449677877539395
# On day 2016-11-07
# Heldout Stouffer's Z (n=1474449) 0.7306196771550774
# On day 2016-11-08
# Heldout Stouffer's Z (n=1474697) 0.7509887294362164
# On day 2016-11-09
# Heldout Stouffer's Z (n=1474912) 0.749235430089984
# On day 2016-11-10
# Heldout Stouffer's Z (n=1475134) 0.7495505969135128
# On day 2016-11-11
# Heldout Stouffer's Z (n=1475344) 0.7549458856414312
# On day 2016-11-12
# Heldout Stouffer's Z (n=1475577) 0.7361019637339791
# On day 2016-11-13
# Heldout Stouffer's Z (n=1475801) 0.7230960623581809
# On day 2016-11-14
# Heldout Stouffer's Z (n=1476040) 0.7062101355524408
# On day 2016-11-15
# Heldout Stouffer's Z (n=1476272) 0.7350135115570748
# On day 2016-11-16
# Heldout Stouffer's Z (n=1476502) 0.7240138877041974
# On day 2016-11-17
# Heldout Stouffer's Z (n=1476720) 0.7151428265607974
# On day 2016-11-18
# Heldout Stouffer's Z (n=1476962) 0.7217892129687287
# On day 2016-11-19

# %% [markdown]
# Sanity check for each year

# %%
def load_data(year, spanlength):
  all_query_stats_chisqtoz = np.load("analysis/"+str(year)+"_"+str(spanlength)+"_all_query_stats_chisqtoz.npy")
  all_heldout_stats_chisqtoz = np.load("analysis/"+str(year)+"_"+str(spanlength)+"_all_heldout_stats_chisqtoz.npy")
  span_start_timestamps = np.load("analysis/"+str(year)+"_"+str(spanlength)+"_span_start_timestamps.npy")
  query_deviceflags = np.load("analysis/"+str(year)+"_"+str(spanlength)+"_query_deviceflags.npy")
  heldout_deviceflags = np.load("analysis/"+str(year)+"_"+str(spanlength)+"_heldout_deviceflags.npy")

  return (all_query_stats_chisqtoz,
          all_heldout_stats_chisqtoz,
          span_start_timestamps,
          query_deviceflags, heldout_deviceflags)


def define_events(query_stats, sliding_window_length, min_score):
  #get the event significance for sliding windows of size sliding_window_length
  cumsum_query_stats = np.pad(np.cumsum(query_stats), [(1,0)]) #also pad with a zero at the start
  sliding_window_query_stats = (cumsum_query_stats[sliding_window_length:] - cumsum_query_stats[:-sliding_window_length])/np.sqrt(sliding_window_length)
  argsort_sliding_window_query_stats = np.argsort(-sliding_window_query_stats) #sort in desc order
  masked_window_starts = np.zeros_like(sliding_window_query_stats) #used to track included windows
  events_start_end_idxs = []
  #march down the argsort list until dip below minscore
  for sliding_window_idx in argsort_sliding_window_query_stats:
    if (masked_window_starts[sliding_window_idx]==0): #this window does not overlap with a previously-included window
      if (sliding_window_query_stats[sliding_window_idx] >= min_score):
        events_start_end_idxs.append((sliding_window_idx, sliding_window_idx+sliding_window_length))
        #mask out the start idx positions of all overlapping windows
        masked_window_starts[max(sliding_window_idx-(sliding_window_length-1),0):
                             (sliding_window_idx+sliding_window_length)] = 1
      else:
        break
  #do a sanity check on all the event start & ends to ensure non-overlapping and
  # defined appropriately
  event_def_sanity_check = np.zeros_like(query_stats)
  for (event_start_idx, event_end_idx) in events_start_end_idxs:
    #print(event_start_idx, event_end_idx)
    assert np.sum(query_stats[event_start_idx:event_end_idx])/np.sqrt(sliding_window_length) >= min_score
    assert np.sum(event_def_sanity_check[event_start_idx:event_end_idx]) == 0 #assert non-overlapping
    event_def_sanity_check[event_start_idx:event_end_idx] = 1
    assert np.sum(event_def_sanity_check[event_start_idx:event_end_idx]) == sliding_window_length
  return events_start_end_idxs

# %%
import numpy as np
import scipy

SPANLENGTH = 60 #specify span in seconds
sliding_window_length = 1 #event duartion ends up being span length times this

allyears_heldout_event_stats = []

for year in range(1999, 2023):
  print("Analysis for year", year)
  (all_query_stats_chisqtoz, all_heldout_stats_chisqtoz, span_start_timestamps,
   query_deviceflags, heldout_deviceflags) = load_data(year, SPANLENGTH)

  from matplotlib import pyplot as plt

  print(scipy.stats.normaltest(all_query_stats_chisqtoz))
  print(scipy.stats.normaltest(all_heldout_stats_chisqtoz))

  event_start_end_idxs = define_events(query_stats=all_query_stats_chisqtoz,
                                       sliding_window_length=sliding_window_length,
                                       min_score=1.0)
  print(len(event_start_end_idxs))
  heldout_event_stats = np.array([np.sum(all_heldout_stats_chisqtoz[x[0]:x[1]])/np.sqrt(sliding_window_length)
                         for x in event_start_end_idxs])
  plt.plot(np.arange(len(heldout_event_stats))+1, np.cumsum(heldout_event_stats)/np.sqrt(np.arange(len(heldout_event_stats))+1))
  plt.plot(plt.xlim(), [0,0], color="black")
  plt.show()

  allyears_heldout_event_stats.extend(heldout_event_stats)
  plt.plot(np.arange(len(allyears_heldout_event_stats))+1, np.cumsum(allyears_heldout_event_stats)/np.sqrt(np.arange(len(allyears_heldout_event_stats))+1))
  plt.plot(plt.xlim(), [0,0], color="black")
  plt.show()

#  plt.hist(all_query_stats_chisqtoz, bins=100, alpha=0.5, density=True)
#  plt.hist(all_heldout_stats_chisqtoz, bins=100, alpha=0.5, density=True)
#  plt.show()

  #sort the query indices in descending order
#  sorted_query_indices = np.argsort(-all_query_stats_chisqtoz)
#  resorted_heldout_stats_chisqtoz = all_heldout_stats_chisqtoz[sorted_query_indices]

#  cumsum_resorted_heldout_stats_chisqtoz = (np.cumsum(resorted_heldout_stats_chisqtoz)/
#                                            np.sqrt(np.arange(len(resorted_heldout_stats_chisqtoz)) + 1))

#  plt.plot(all_query_stats_chisqtoz[sorted_query_indices[::100]],
#          cumsum_resorted_heldout_stats_chisqtoz[::100])
#  plt.show()
# Out:
# Analysis for year 1999
# NormaltestResult(statistic=0.09843771268634055, pvalue=0.9519727616205927)
# NormaltestResult(statistic=0.43799539804249565, pvalue=0.8033235665819578)
# 73591
# Analysis for year 2000
# NormaltestResult(statistic=1.4317580507811303, pvalue=0.4887622884496925)
# NormaltestResult(statistic=4.071380038921698, pvalue=0.1305903415310335)
# 83899
# Analysis for year 2001
# NormaltestResult(statistic=1.4623726391780651, pvalue=0.4813376309893833)
# NormaltestResult(statistic=2.211948071851152, pvalue=0.3308884280102325)
# 83586
# Analysis for year 2002
# NormaltestResult(statistic=0.45753503377518856, pvalue=0.7955134554527303)
# NormaltestResult(statistic=0.2385131911108434, pvalue=0.8875800224509067)
# 82152
# Analysis for year 2003
# NormaltestResult(statistic=1.459274630287939, pvalue=0.48208380288195285)
# NormaltestResult(statistic=0.13078191296909403, pvalue=0.9367011823807688)
# 83186
# Analysis for year 2004
# NormaltestResult(statistic=4.9945242530031955, pvalue=0.08231004489978692)
# NormaltestResult(statistic=2.8652997899857864, pvalue=0.2386756181941466)
# 83916
# Analysis for year 2005
# NormaltestResult(statistic=0.6257077046187802, pvalue=0.7313567908646804)
# NormaltestResult(statistic=0.7030625430075277, pvalue=0.7036098466799932)
# 82915
# Analysis for year 2006
# NormaltestResult(statistic=6.593469727486346, pvalue=0.03700379279038748)
# NormaltestResult(statistic=2.1825471106248857, pvalue=0.33578857595134576)
# 83610
# Analysis for year 2007
# NormaltestResult(statistic=0.22649797627326634, pvalue=0.8929283038806016)
# NormaltestResult(statistic=2.1761558615867163, pvalue=0.33686334652485184)
# 83197
# Analysis for year 2008
# NormaltestResult(statistic=0.2707480328645144, pvalue=0.8733891886836335)
# NormaltestResult(statistic=5.633127869390139, pvalue=0.05981110489412774)
# 83239
# Analysis for year 2009
# NormaltestResult(statistic=1.1588053880845213, pvalue=0.5602328970940731)
# NormaltestResult(statistic=1.4439395455415382, pvalue=0.48579440830089426)
# 83728
# Analysis for year 2010
# NormaltestResult(statistic=0.5617924908887991, pvalue=0.7551066771737049)
# NormaltestResult(statistic=1.0819944941817057, pvalue=0.5821673980503907)
# 82917
# Analysis for year 2011
# NormaltestResult(statistic=1.2996275013250609, pvalue=0.5221430164962038)
# NormaltestResult(statistic=2.8290389543512564, pvalue=0.2430423728011493)
# 82185
# Analysis for year 2012
# NormaltestResult(statistic=8.497918103134316, pvalue=0.014279089971788695)
# NormaltestResult(statistic=4.856877269270127, pvalue=0.08817439761029337)
# 83518
# Analysis for year 2013
# NormaltestResult(statistic=3.3186720418785773, pvalue=0.19026527032532523)
# NormaltestResult(statistic=7.441812068092806, pvalue=0.024212020989544274)
# 83181
# Analysis for year 2014
# NormaltestResult(statistic=1.641808788594493, pvalue=0.44003351069597074)
# NormaltestResult(statistic=2.3551243567477265, pvalue=0.30802874317258894)
# 83134
# Analysis for year 2015
# NormaltestResult(statistic=0.7068758310333388, pvalue=0.702269591279385)
# NormaltestResult(statistic=2.1132516566380253, pvalue=0.3476267861397284)
# 82370
# Analysis for year 2016
# NormaltestResult(statistic=0.5443630970373848, pvalue=0.761715960131824)
# NormaltestResult(statistic=2.611408913900041, pvalue=0.27098157293882125)
# 82528
# Analysis for year 2017
# NormaltestResult(statistic=69.22796685295685, pvalue=9.275514340212473e-16)
# NormaltestResult(statistic=58.31329987701607, pvalue=2.1748425484751086e-13)
# 82735
# Analysis for year 2018
# NormaltestResult(statistic=3.205662739878761, pvalue=0.20132568276694085)
# NormaltestResult(statistic=0.2408441285439441, pvalue=0.8865461782748516)
# 75917
# Analysis for year 2019
# NormaltestResult(statistic=1.5984658734373594, pvalue=0.44967376009008886)
# NormaltestResult(statistic=0.11964625063677221, pvalue=0.9419311226185386)
# 82638
# Analysis for year 2020
# NormaltestResult(statistic=6.037197240921223, pvalue=0.048869655332807925)
# NormaltestResult(statistic=2.552823213777715, pvalue=0.2790367998125793)
# 82841
# Analysis for year 2021
# NormaltestResult(statistic=0.22421214534889763, pvalue=0.893949428864341)
# NormaltestResult(statistic=7.245884863970363, pvalue=0.02670398611599254)
# 82507
# Analysis for year 2022
# NormaltestResult(statistic=0.5909617803944544, pvalue=0.7441736355986412)
# NormaltestResult(statistic=8.759419975857128, pvalue=0.012528991653059658)
# 82170
